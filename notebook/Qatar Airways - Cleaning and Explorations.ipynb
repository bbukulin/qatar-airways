# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("qatar_airways_reviews.csv")

# %%
df.head()
# Out:
#   Date Published  Rating  Max Rating                                  Title  \
# 0     2024-03-02     1.0        10.0             “marred by inconveniences”
# 1     2024-02-29     1.0        10.0                "seat wouldn't stay up"
# 2     2024-02-29     1.0        10.0  "no attempt to address our complaint"
# 3     2024-02-25    10.0        10.0          “I hope they update the A380”
# 4     2024-02-22     7.0        10.0             "I’d rate them maybe 7/10"
#
#              Author         Country        Date  \
# 0           Mary Le  United Kingdom  2024-03-02
# 1     Brian English          Canada  2024-02-29
# 2     Wayne Burgess       Australia  2024-02-29
# 3  Alwaleed Althani           Qatar  2024-02-25
# 4         W Warnock  United Kingdom  2024-02-22
#
#                                          Review Body Type Of Traveller  \
# 0   The delay of my flight from Haneda to Doha ca...      Solo Leisure
# 1    They convinced me that I needed to pay $1500...    Couple Leisure
# 2    I have sent 5 emails and have only received ...          Business
# 3   We flew on probably the first A380 the airlin...    Couple Leisure
# 4    Service was ok, pretty good on my aisle and ...    Couple Leisure
#
#         Seat Type                              Route     Date Flown  \
# 0   Economy Class  Tokyo to London Heathrow via Doha     March 2024
# 1  Business Class                   Doha to Montreal  February 2024
# 2   Economy Class                      Doha to Perth  November 2023
# 3     First Class            Doha to London Heathrow  February 2024
# 4  Business Class                   Auckland to Doha  February 2024
#
#   Recommended  Aircraft  Verified
# 0          no       NaN       0.0
# 1          no       NaN       1.0
# 2          no      A380       1.0
# 3         NaN  A380-800       1.0
# 4          no      A350       1.0

# %% [markdown]
# ### Opći pregled skupa podataka

# %%
# Pregled detalja dataseta
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2369 entries, 0 to 2368
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date Published     2369 non-null   object
#  1   Rating             2368 non-null   float64
#  2   Max Rating         2368 non-null   float64
#  3   Title              2369 non-null   object
#  4   Author             2369 non-null   object
#  5   Country            2369 non-null   object
#  6   Date               2369 non-null   object
#  7   Review Body        2369 non-null   object
#  8   Type Of Traveller  1934 non-null   object
#  9   Seat Type          2369 non-null   object
#  10  Route              1931 non-null   object
#  11  Date Flown         1925 non-null   object
#  12  Recommended        588 non-null    object
#  13  Aircraft           1281 non-null   object
#  14  Verified           1252 non-null   float64
# dtypes: float64(3), object(12)
# memory usage: 277.7+ KB

# %% [markdown]
# Funkcija `df.describe()` pruža deskriptivnu statistiku o stupcima u DataFrame-u - sažetak o središnjoj tendenciji, disperziji i obliku distribucije podataka.<br> U nastavku je objašnjen što svaki od izlaza navedene funkcije obično predstavlja
#
# - **count**: Broj nepraznih promatranja.
# - **mean**: Srednja vrijednost ili prosjek.
# - **std**: Standardna devijacija, koja mjeri disperziju vrijednosti.
# - **min**: Minimalna vrijednost.
# - **25%**: 25. percentil, također poznat kao prvi kvartil.
# - **50%**: 50. percentil, također poznat kao medijan ili drugi kvartil.
# - **75%**: 75. percentil, također poznat kao treći kvartil.
# - **max**: Maksimalna vrijednost.
#
# Ovaj sažetak pomaže nam razumjeti distribuciju numeričkih podataka u DataFrame-u, identificirati _outlier_ vrijednosti i otkriti potencijalne probleme u datasetu.

# %%
# Opis numeričkih vrijednosti
df.describe()
# Out:
#             Rating  Max Rating     Verified
# count  2368.000000      2368.0  1252.000000
# mean      7.311233        10.0     0.920128
# std       2.861367         0.0     0.271204
# min       1.000000        10.0     0.000000
# 25%       5.000000        10.0     1.000000
# 50%       8.000000        10.0     1.000000
# 75%      10.000000        10.0     1.000000
# max      10.000000        10.0     1.000000

# %% [markdown]
# Iz tablice pregleda vidimo dva stupca pod nazivom `Date Published` i `Date`.<br> Prvi korak je utvrditi sadrže li oba stupca iste podatke.<br> Ako stupci sadrže identične podatke, možemo ukloniti jedan od njih kako bismo izbjegli redundanciju.

# %%
(df['Date Published'] == df['Date']).value_counts()
# Out:
# True    2369
# Name: count, dtype: int64

# %% [markdown]
# `Output[24]` iznad potvrđuje pretpostavku identičnih podataka u stupcima `Date Published` i `Date`.<br> Imajući to na umu, možemo ukloniti stupac `Date` iz tablice koristeći naredbu `df.drop('Date', axis = 1, inplace = True)`

# %%
df.sample(5)
# Out:
#      Date Published  Rating  Max Rating                              Title  \
# 1460     2017-02-12     8.0        10.0  "staff are excellent and genuine"
# 1431     2017-03-14     8.0        10.0   "good flights with average food"
# 560      2021-07-20    10.0        10.0       "can recommend this airline"
# 1576     2016-07-14     8.0        10.0  "Qatar Airways do not dissapoint"
# 17       2024-01-18    10.0        10.0   "genuine warmth and hospitality"
#
#               Author         Country  \
# 1460      W FIischer          France
# 1431  Michael Schade         Germany
# 560     Ronald Kakas        Slovakia
# 1576        K Ruslan  United Kingdom
# 17        David Owen       Australia
#
#                                             Review Body Type Of Traveller  \
# 1460  ✅ Verified Review |  Bangkok to Doha, 09 Feb 2...      Solo Leisure
# 1431  ✅ Verified Review |  Brussels to Singapore via...      Solo Leisure
# 560     This was not my first experience with Qatar ...      Solo Leisure
# 1576  Bangkok to Edinburgh via Doha. Qatar Airways d...    Couple Leisure
# 17      I have flown with Qatar in economy, business...      Solo Leisure
#
#            Seat Type                           Route     Date Flown  \
# 1460   Economy Class                 Bangkok to Doha  February 2017
# 1431  Business Class  Brussels to Singapore via Doha     March 2017
# 560    Economy Class      Bangkok to Vienna via Doha      July 2021
# 1576   Economy Class              BKK to EDI via DOH      July 2016
# 17       First Class        London to Perth via Doha   January 2024
#
#      Recommended                 Aircraft  Verified
# 1460         NaN                     A380       NaN
# 1431         NaN               B787, A350       NaN
# 560          NaN                      NaN       1.0
# 1576         NaN  Boeing 777 / Boeing 787       NaN
# 17           NaN                     A380       1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2369 entries, 0 to 2368
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date Published     2369 non-null   object
#  1   Rating             2368 non-null   float64
#  2   Max Rating         2368 non-null   float64
#  3   Title              2369 non-null   object
#  4   Author             2369 non-null   object
#  5   Country            2369 non-null   object
#  6   Review Body        2369 non-null   object
#  7   Type Of Traveller  1934 non-null   object
#  8   Seat Type          2369 non-null   object
#  9   Route              1931 non-null   object
#  10  Date Flown         1925 non-null   object
#  11  Recommended        588 non-null    object
#  12  Aircraft           1281 non-null   object
#  13  Verified           1252 non-null   float64
# dtypes: float64(3), object(11)
# memory usage: 259.2+ KB

# %%
# Provjera dupliciranih vrijednosti
df.duplicated().any()
# Out:
# True

# %%
# Prikaz dupliciranih vrijednosti
df[df.duplicated()]
# Out:
#      Date Published  Rating  Max Rating                          Title  \
# 2104     2014-10-13     4.0        10.0  Qatar Airways customer review
#
#             Author         Country  \
# 2104  Geoff Harris  United Kingdom
#
#                                             Review Body Type Of Traveller  \
# 2104  Qatar Airways has really gone downhill at leas...               NaN
#
#           Seat Type Route Date Flown Recommended Aircraft  Verified
# 2104  Economy Class   NaN        NaN          no      NaN       NaN

# %%
# Uklanjanje dupliciranih vrijednosti zadržavajući prvi zapis kao ispravan
df.drop_duplicates(keep='first', inplace=True)

# %%
# Ponovna provjera dupliciranih vrijednosti
df.duplicated().any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2368 entries, 0 to 2368
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date Published     2368 non-null   object
#  1   Rating             2367 non-null   float64
#  2   Max Rating         2367 non-null   float64
#  3   Title              2368 non-null   object
#  4   Author             2368 non-null   object
#  5   Country            2368 non-null   object
#  6   Review Body        2368 non-null   object
#  7   Type Of Traveller  1934 non-null   object
#  8   Seat Type          2368 non-null   object
#  9   Route              1931 non-null   object
#  10  Date Flown         1925 non-null   object
#  11  Recommended        587 non-null    object
#  12  Aircraft           1281 non-null   object
#  13  Verified           1252 non-null   float64
# dtypes: float64(3), object(11)
# memory usage: 277.5+ KB

# %%
# Provjera NULL vrijednosti
df.isna().sum()
# Out:
# Date Published          0
# Rating                  1
# Max Rating              1
# Title                   0
# Author                  0
# Country                 0
# Review Body             0
# Type Of Traveller     434
# Seat Type               0
# Route                 437
# Date Flown            443
# Recommended          1781
# Aircraft             1087
# Verified             1116
# dtype: int64

# %%
# Prikaz NULL vrijednosti u stupcu Rating
df[df['Rating'].isna()]
# Out:
#      Date Published  Rating  Max Rating  \
# 1308     2017-09-16     NaN         NaN
#
#                                       Title      Author         Country  \
# 1308  "fabulous service from Qatar Airways"  R Kirchner  United Kingdom
#
#                                             Review Body Type Of Traveller  \
# 1308  ✅ Verified Review |  Munich to Doha onboard a ...      Solo Leisure
#
#           Seat Type           Route      Date Flown Recommended Aircraft  \
# 1308  Economy Class  Munich to Doha  September 2017         NaN     A350
#
#       Verified
# 1308       NaN

# %%
# Uklanjanje zapisa jer ne možemo zamijeniti NULL vrijednost u Rating stupcu za gornji zapis
df.dropna(subset=['Rating'], inplace = True)

# %%
df.isna().sum().sort_values()
# Out:
# Date Published          0
# Rating                  0
# Max Rating              0
# Title                   0
# Author                  0
# Country                 0
# Review Body             0
# Seat Type               0
# Type Of Traveller     434
# Route                 437
# Date Flown            443
# Aircraft             1087
# Verified             1115
# Recommended          1780
# dtype: int64

# %% [markdown]
# <hr>

# %% [markdown]
# ### Čišćenje podataka - Tipovi putnika
#
# Poglavlje u nastavku fokusira se na obradu nedostajućih vrijednosti u stupcu `Type of Traveller`<br>
#
# **TLDR**:
# - U skupu podataka otkriveno je ukupno `434` nedostajućih vrijednosti za stupac `Type of Traveller`
# - Trenutni skup podataka ne sadrži ovisni stupac ili dodatne podatke koji mogu poslužiti za nedostajuće vrijednosti
# - Odlučeno je nedostajuće vrijednosti zamijeniti vrijednošću `Unknown`

# %%
# Prikaz vrsta kategorija u stupcu Type of Traveller za segregaciju
df['Type Of Traveller'].value_counts()
# Out:
# Type Of Traveller
# Solo Leisure      841
# Couple Leisure    458
# Business          325
# Family Leisure    309
# Name: count, dtype: int64

# %%
# Prikaz Non-Null vrijednosti u stupcu
df['Type Of Traveller'].notna().sum()
# Out:
# 1933

# %%
# Prikaz NULL vrijednosti u stupcu 
df['Type Of Traveller'].isna().sum()
# Out:
# 434

# %%
# Zbroj NULL i Non-Null vrijednosti
(df['Type Of Traveller'].notna().sum()) + (df['Type Of Traveller'].isna().sum())
# Out:
# 2367

# %% [markdown]
# Možemo potvrditi zastupljenost ukupno `434` nedostajućih vrijednosti koje treba nadomjestiti.<br>
# Budući da nemamo niti jedan ovisni stupac ili podatke za popunjavanje nedostajućih vrijednosti nekim smislenim vrijednostima, ove ćemo podatke nadomjestiti vrijednošću `Unknown`.

# %%
df['Type Of Traveller'].fillna("Unknown", inplace = True)

# %%
df.isna().sum().sort_values()
# Out:
# Date Published          0
# Rating                  0
# Max Rating              0
# Title                   0
# Author                  0
# Country                 0
# Review Body             0
# Type Of Traveller       0
# Seat Type               0
# Route                 437
# Date Flown            443
# Aircraft             1087
# Verified             1115
# Recommended          1780
# dtype: int64

# %% [markdown]
# <hr>

# %% [markdown]
# ### Čišćenje podataka - Datum leta
#
# Poglavlje u nastavku fokusira se na obradu nedostajućih vrijednosti u stupcu `Date Flown` <br>
#
# Podaci u stupcu `Date Published` odnose se na datum kada je korisnik objavio recenziju. <br> Iako ne možemo tvrditi da je datum leta i datum objave recenzije uvijek isti, ipak se možemo poslužiti podacima iz stupca `Date Published` kako bismo popunili nedostajuće vrijednosti u stupcu `Date Flown`.
#
# **TLDR**:
# - Pretvaranje `dateTime` tipa podatka iz `Object` u `DateTime[ms]` za stupac `Date Published`
# - Korištenje `fillna` za nadomještanje vrijednosti u `Date Flown` stupcu iz `Date Published` - format Month Year
# - Pretvaranje datuma u odgovarajući format i popunjavanje praznih vrijednosti određenim formatom iz stupca `Date Published`
# - Pretvaranje `Date Flown` u format Month Year iz uobičajenog formata datuma

# %% [markdown]
# Prije nego što se mogu iskoristiti datumi iz jednog stupca za drugi, potrebno je provjeriti jesu li tipovi podataka kompatibilni

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2367 entries, 0 to 2368
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date Published     2367 non-null   object
#  1   Rating             2367 non-null   float64
#  2   Max Rating         2367 non-null   float64
#  3   Title              2367 non-null   object
#  4   Author             2367 non-null   object
#  5   Country            2367 non-null   object
#  6   Review Body        2367 non-null   object
#  7   Type Of Traveller  2367 non-null   object
#  8   Seat Type          2367 non-null   object
#  9   Route              1930 non-null   object
#  10  Date Flown         1924 non-null   object
#  11  Recommended        587 non-null    object
#  12  Aircraft           1280 non-null   object
#  13  Verified           1252 non-null   float64
# dtypes: float64(3), object(11)
# memory usage: 277.4+ KB

# %% [markdown]
# Oba atributa su tipa `object`, stoga je obavezno pretvoriti stupac `Date Published` iz tipa `object` u format `Datetime`<br> Isto postupak moramo provesti i nad stupcem `Date Flown`

# %%
df['Date Published'] = pd.to_datetime(df['Date Published'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2367 entries, 0 to 2368
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date Published     2367 non-null   datetime64[ns]
#  1   Rating             2367 non-null   float64
#  2   Max Rating         2367 non-null   float64
#  3   Title              2367 non-null   object
#  4   Author             2367 non-null   object
#  5   Country            2367 non-null   object
#  6   Review Body        2367 non-null   object
#  7   Type Of Traveller  2367 non-null   object
#  8   Seat Type          2367 non-null   object
#  9   Route              1930 non-null   object
#  10  Date Flown         1924 non-null   object
#  11  Recommended        587 non-null    object
#  12  Aircraft           1280 non-null   object
#  13  Verified           1252 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(10)
# memory usage: 277.4+ KB

# %%
# Korištenje filnna za nadomještanje vrijednosti u stupcu Date Flown iz stupca Date Published u Month Year formatu
# Pretvaranje datetime formata i popunjavanje null vijednosti određenim formatom iz stupca Date Published 

df['Date Flown'] = pd.to_datetime(df['Date Flown'], format='%B %Y', errors='coerce')

df['Date Flown'] = df['Date Flown'].fillna(df['Date Published'].dt.strftime('%B %Y'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2367 entries, 0 to 2368
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date Published     2367 non-null   datetime64[ns]
#  1   Rating             2367 non-null   float64
#  2   Max Rating         2367 non-null   float64
#  3   Title              2367 non-null   object
#  4   Author             2367 non-null   object
#  5   Country            2367 non-null   object
#  6   Review Body        2367 non-null   object
#  7   Type Of Traveller  2367 non-null   object
#  8   Seat Type          2367 non-null   object
#  9   Route              1930 non-null   object
#  10  Date Flown         2367 non-null   datetime64[ns]
#  11  Recommended        587 non-null    object
#  12  Aircraft           1280 non-null   object
#  13  Verified           1252 non-null   float64
# dtypes: datetime64[ns](2), float64(3), object(9)
# memory usage: 277.4+ KB

# %%
df.sample(10)
# Out:
#      Date Published  Rating  Max Rating                               Title  \
# 514      2021-11-13    10.0        10.0              "We were so impressed"
# 496      2022-01-06     1.0        10.0         "approx 1.5hrs to check in"
# 1379     2017-05-20     8.0        10.0  "received good service throughout"
# 1531     2016-10-08     9.0        10.0             "staff are always nice"
# 584      2021-05-09     1.0        10.0    "not allowed to board my flight"
# 1885     2015-07-19     5.0        10.0       Qatar Airways customer review
# 1369     2017-06-09     9.0        10.0    "flight was a pleasure to be on"
# 1150     2018-04-18    10.0        10.0      "crew on board were fantastic"
# 1364     2017-06-12    10.0        10.0        "They have the best service"
# 15       2024-01-25     2.0        10.0   "no covered canopy on the stairs"
#
#                Author         Country  \
# 514      Joel Barnaby   United States
# 496            B Jing  United Kingdom
# 1379  Anders Pedersen         Vietnam
# 1531  Richard Mueller         Germany
# 584             C Han           Qatar
# 1885     Michael Beer         Austria
# 1369    Neil Solomons          Canada
# 1150           C Down  United Kingdom
# 1364       C Lariggas     Philippines
# 15            P Craig       Australia
#
#                                             Review Body Type Of Traveller  \
# 514    We were so impressed with the Q-Suite seats o...      Solo Leisure
# 496     Heathrow check had to queue for approx 1.5hr...    Couple Leisure
# 1379  ✅ Verified Review | Travelled Ho Chi Minh City...    Family Leisure
# 1531  Munich to Bangkok return via Doha with Qatar A...    Couple Leisure
# 584     I was not allowed to board my flight from Qa...    Family Leisure
# 1885  Our flight started with waiting on a bus for o...    Couple Leisure
# 1369  ✅ Verified Review |  Singapore to Madrid via D...          Business
# 1150    Birmingham to Manila via Doha. Check in at B...      Solo Leisure
# 1364  ✅ Verified Review |  Doha to Manila. They have...    Family Leisure
# 15      When my flight with Qatar was delayed throug...      Solo Leisure
#
#            Seat Type                                    Route Date Flown  \
# 514   Business Class                    Philadelphia to Dubai 2021-11-01
# 496    Economy Class                  London to Male via Doha 2021-12-01
# 1379   Economy Class  Ho Chi Minh City to Copenhagen via Doha 2017-05-01
# 1531   Economy Class                       MUC to BKK via DOH 2016-09-01
# 584    Economy Class          Doha to Keflavik via Copenhagen 2021-05-01
# 1885   Economy Class                           Doha to Vienna 2015-07-01
# 1369  Business Class             Singapore to Madrid via Doha 2017-05-01
# 1150  Business Class            Birmingham to Manila via Doha 2018-04-01
# 1364   Economy Class                           Doha to Manila 2017-06-01
# 15     Economy Class                          Tbilisi to Doha 2023-12-01
#
#      Recommended                   Aircraft  Verified
# 514          NaN                        NaN       1.0
# 496           no                        NaN       1.0
# 1379         NaN  A340-600 / Boeing 787-800       NaN
# 1531         NaN          A380 / Boeing 777       NaN
# 584           no                        NaN       1.0
# 1885         NaN                        NaN       NaN
# 1369         NaN                       A350       NaN
# 1150         NaN           Boeing 787 / 777       1.0
# 1364         NaN           Boeing 777-300ER       NaN
# 15           NaN                        NaN       1.0

# %%
# Pretvaranje Date Flown u Month Year format

df['Date Flown'] = df['Date Flown'].dt.strftime('%B %Y')

# %% [markdown]
# <hr>

# %% [markdown]
# ### Čišćenje podataka - Verified stupac
#
# Poglavlje u nastavku fokusira se na obradu nedostajećih podataka u stupcu `Verified`<br>
#
# **TLDR**:
# - Zastupljenost ukupno `368` zapisa čija je vrijednost `NaN` u stupcu `Verified`, ali sadrži tekst `Verified Review` u stupcu `Review Body`, što će se zamijeniti s vrijednošću `1.0`
# - Preostali dio zapisa označit ćemo s `0.0`, odnosno kao neverificirane recenzije

# %%
# Provjera nedostajućih vrijednosti
df.isna().sum()
# Out:
# Date Published          0
# Rating                  0
# Max Rating              0
# Title                   0
# Author                  0
# Country                 0
# Review Body             0
# Type Of Traveller       0
# Seat Type               0
# Route                 437
# Date Flown              0
# Recommended          1780
# Aircraft             1087
# Verified             1115
# dtype: int64

# %%
# Prikaz jedinstvenih vrijednosti u stupcu Verified
df['Verified'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
# Pretraživanje i odabir zapisa koji sadrže 'Verified Review' u Review Body stupcu 
verified_reviews = df[df['Review Body'].str.contains('Verified Review', case=False)].copy()

# %%
# Prikaz svih recenzija koje sadrže ciljani tekst koji može biti korišten za ispravak NaN vrijednosti u Verified stupcu  
verified_reviews
# Out:
#      Date Published  Rating  Max Rating  \
# 1255     2017-11-18    10.0        10.0
# 1256     2017-11-18    10.0        10.0
# 1257     2017-11-17    10.0        10.0
# 1258     2017-11-17     6.0        10.0
# 1259     2017-11-12     6.0        10.0
# ...             ...     ...         ...
# 1661     2016-03-31     5.0        10.0
# 1662     2016-03-30    10.0        10.0
# 1664     2016-03-28    10.0        10.0
# 1665     2016-03-26    10.0        10.0
# 1666     2016-03-24     1.0        10.0
#
#                                       Title        Author         Country  \
# 1255           "Great service in the cabin"     G Stanton       Hong Kong
# 1256    "100% happy with what they offered"    Anton Gots       Hong Kong
# 1257                   "Crew are wonderful"    D Anderson           Qatar
# 1258    "flight was good although food not"      G Litten       Australia
# 1259        "Service out of CPH was rushed"        D Webb  United Kingdom
# ...                                     ...           ...             ...
# 1661                  "all flights on time"    C Stanhope  United Kingdom
# 1662             "experience was excellent"         C Kay  United Kingdom
# 1664    "very polite, friendly and smiling"     M Mawanga  United Kingdom
# 1665  "fantastic business class experience"       A Ahmed  United Kingdom
# 1666                "no staff were waiting"  Alan Hepburn           China
#
#                                             Review Body Type Of Traveller  \
# 1255  ✅ Verified Review |  Kiev to Doha. Plane took ...      Solo Leisure
# 1256  ✅ Verified Review |  Flew Doha to Hong Kong. F...      Solo Leisure
# 1257  ✅ Verified Review |  Flew Paris CDG to Doha. T...          Business
# 1258  ✅ Verified Review |  Sydney to Amsterdam via D...    Couple Leisure
# 1259  ✅ Verified Review |  Copenhagen to Male via Do...    Couple Leisure
# ...                                                 ...               ...
# 1661  ✅ Verified Review |  London to Colombo via Doh...    Couple Leisure
# 1662  ✅ Verified Review |  Edinburgh to Male via Doh...    Couple Leisure
# 1664  ✅ Verified Review |  London Heathrow to Cape T...      Solo Leisure
# 1665  ✅ Verified Review |  Copenhagen to Melbourne v...      Solo Leisure
# 1666  ✅ Verified Review |  A recent trip from Dubai ...    Couple Leisure
#
#            Seat Type                         Route     Date Flown Recommended  \
# 1255   Economy Class                  Kiev to Doha  November 2017         NaN
# 1256   Economy Class             Doha to Hong Kong  November 2017         NaN
# 1257  Business Class                 Paris to Doha  November 2017         NaN
# 1258  Business Class  Sydney to Amsterdam via Doha  November 2017          no
# 1259  Business Class   Copenhagen to Male via Doha  November 2017         NaN
# ...              ...                           ...            ...         ...
# 1661   Economy Class            LHR to CNB via DOH     March 2016          no
# 1662  Business Class            EDI to MLE via DOH     March 2016         NaN
# 1664   Economy Class            LHR to CPT via DOH  February 2016         NaN
# 1665  Business Class            CPH to MEL via DOH  February 2016         NaN
# 1666   Economy Class            DXB to LHR via DOH     March 2016          no
#
#                       Aircraft  Verified
# 1255                      A320       NaN
# 1256                Boeing 787       NaN
# 1257                  A350-900       NaN
# 1258                      A380       NaN
# 1259         Boeing 787 / A350       NaN
# ...                        ...       ...
# 1661   Boeing 777 / 787 / A340       NaN
# 1662  Boeing 787 / A330 / A320       NaN
# 1664                       NaN       NaN
# 1665  Boeing 787-8 / 777-300ER       NaN
# 1666                       NaN       NaN
#
# [368 rows x 14 columns]

# %% [markdown]
# Iz rezultata iznad vidljiva je zastupljenost `368` zapisa sa vrijednošću `NaN` koji se mogu zamijeniti s vrijednošću `1.0`, označavajući ih kao verificirane recenzije. Ostatak zapisa označit ćemo s `0.0` kao neverificirane recenzije.

# %%
verified_reviews = verified_reviews.to_csv("verified_reviews.csv")

# Checkpointara 12:34

# %%
verified_reviews = pd.read_csv("verified_reviews.csv")

# %%
verified_reviews['Verified'].isna().sum()
# Out:
# 368

# %%
# Prikaz postotka za svaku kategoriju unutar Verified stupca
df['Verified'].value_counts(normalize = True)*100
# Out:
# Verified
# 1.0    92.01278
# 0.0     7.98722
# Name: proportion, dtype: float64

# %% [markdown]
# Na temelju rezultata iznad, možemo zaključiti da postoji ukupno 92% verificiranih recenzija.

# %%
# Null vrijednosti u stupcu Verified
df['Verified'].isna().sum()
# Out:
# 1115

# %% [markdown]
# Ažuriranje vrijednosti u stupcu `Verified` korištenjem `.loc` metode. <br>
# Kao prvi korak potrebno je stvoriti novi DataFrame koji sadrži sve zapise iz izvornog `df` DataFrame-a u kojima stupac `Review Body` sadrži tekst `Verified Review`, pri tome omogućiti neosjetljivost na velika i mala slova prilikom pretraživanja. <br>
#
# Kao drugi korak procesa, koristeći indekse zapisa iz `verified_rows`, lociramo iste zapise u izvornom `df` DataFrame-u i ažuriramo stupac `Verified`.

# %%
verified_rows = df[df['Review Body'].str.contains('Verified Review', case=False)]

df.loc[verified_rows.index, 'Verified'] = df.loc[verified_rows.index, 'Verified'].fillna(1.0)

# %%
# Prikaz preostalih NULL vrijednosti nakon ažuriranja Verified stupca
df['Verified'].isna().sum()
# Out:
# 747

# %%
# Provjera zastupljenosti bilo kojih NULL vrijednosti za uvjet 'Verified Review' u podacima
df[df['Review Body'].str.contains('Verified Review', case=False)].isna().sum()
# Out:
# Date Published         0
# Rating                 0
# Max Rating             0
# Title                  0
# Author                 0
# Country                0
# Review Body            0
# Type Of Traveller      0
# Seat Type              0
# Route                  0
# Date Flown             0
# Recommended          286
# Aircraft              79
# Verified               0
# dtype: int64

# %% [markdown]
# Iz rezultata iznad možemo potvrditi da smo uspješno ažurirali vrijednosti `Verified` stupca za sve zapise koji su imali `NaN` vrijednost u istom stupcu, ali su imali `Verified Review` tekst u stupcu `Review Body`

# %% [markdown]
# Preostale zapise koji sadrže `NaN` vrijednosti ažurirat ćemo vrijednošću `0.0`

# %%
not_verified_reviews = df[~df['Review Body'].str.contains('Verified Review', case=False)]

df.loc[not_verified_reviews.index, 'Verified'] = df.loc[not_verified_reviews.index, 'Verified'].fillna(0.0)

# %%
# Konačna provjera ispravnosti čišćenja Verified stupca
df.isna().sum()
# Out:
# Date Published          0
# Rating                  0
# Max Rating              0
# Title                   0
# Author                  0
# Country                 0
# Review Body             0
# Type Of Traveller       0
# Seat Type               0
# Route                 437
# Date Flown              0
# Recommended          1780
# Aircraft             1087
# Verified                0
# dtype: int64

# %% [markdown]
# <hr>

# %% [markdown]
# ### Čišćenje podataka - Recommended stupac
#
# Poglavlje u nastavku fokusira se na obradu nedostajećih podataka u stupcu `Recommended` <br>
#
# **TLDR**:
# - Za ažuriranje nedostajućih vrijednosti u `Recommended` stupcu korišten je stupac `Rating`
# - Za putnike koji su ostavili ocjenu `8.0` ili više od toga, stupac `Recommended` ažuriran je vrijednošću `Yes`
# - Za putnike koji su ostavili ocjenu manju od `8.0`, stupac `Recommended` ažuriran je vrijednošću `No`

# %%
# Prikaz broja putnika čija je vrijednost stupca Recommended 'No'
df['Recommended'].value_counts()
# Out:
# Recommended
# no    587
# Name: count, dtype: int64

# %%
df['Recommended'].isna().sum()
# Out:
# 1780

# %%
# Zbroj NULL vrijednosti i not-null vrijednosti kako bismo dobili ukupan broj zapisa
total = (df['Recommended'].value_counts() + df['Recommended'].isna().sum())
total
# Out:
# Recommended
# no    2367
# Name: count, dtype: int64

# %% [markdown]
# Budući da postoji većinska zastupljenost vrijednosti `NULL`, možemo se poslužiti `Rating` stupcem kojeg ćemo iskoristiti kao parametar za razmatranje preporuke kao `Yes` ili `No`. Prije toga, potrebno je grupirati ocjene dane od strane putnika.

# %%
# Ukupan broj putnika prema danim ocjenama
df['Rating'].value_counts()
# Out:
# Rating
# 10.0    726
# 9.0     412
# 8.0     279
# 7.0     212
# 5.0     154
# 1.0     152
# 6.0     134
# 3.0     109
# 4.0      97
# 2.0      92
# Name: count, dtype: int64

# %%
# Grupiranje po Rating i Recommended stupcima za bolje razumijevanje distribucije podataka
df.groupby(['Rating'])['Recommended'].value_counts()
# Out:
# Rating  Recommended
# 1.0     no             151
# 2.0     no              87
# 3.0     no              96
# 4.0     no              82
# 5.0     no              92
# 6.0     no              52
# 7.0     no              22
# 8.0     no               1
# 9.0     no               3
# 10.0    no               1
# Name: count, dtype: int64

# %%
# Grupiranje po Rating i Recommended stupcima za bolje razumijevanje distribucije podataka
df.groupby(['Rating'])['Recommended'].value_counts().plot(kind='barh', grid = True, legend=True)
plt.title("Recommendation Based on Rating")
plt.xlabel("Count of Travellers")
plt.show()

# %% [markdown]
# Iz gornjeg prikaza možemo pretpostaviti da putnici koji ocijene svoje iskustvo s ocjenom `8.0` ili više imaju vrlo **malu** vjerojatnost da istu uslugu **neće** preporučiti.

# %% [markdown]
# Imajući to na umu, možemo opravdati da se bilo koja ocjena ispod `8.0` smatra kao `Not Recommended` te suprotno tome, bilo koja ocjena uključujući `8.0` i iznad kao `Recommended`.

# %%
rating_mask = df['Rating'] < 8

df.loc[rating_mask, 'Recommended'] = df.loc[rating_mask, 'Recommended'].fillna('no')
df.loc[~rating_mask, 'Recommended'] = df.loc[~rating_mask, 'Recommended'].fillna('Yes')

# %%
grouped = df.groupby(['Rating'])['Recommended'].value_counts()

# %%
print(grouped)
# Out:
# Rating  Recommended
# 1.0     no             152
# 2.0     no              92
# 3.0     no             109
# 4.0     no              97
# 5.0     no             154
# 6.0     no             134
# 7.0     no             212
# 8.0     Yes            278
#         no               1
# 9.0     Yes            409
#         no               3
# 10.0    Yes            725
#         no               1
# Name: count, dtype: int64

# %%
# Postotak preporuka
df['Recommended'].value_counts(normalize=True)*100
# Out:
# Recommended
# Yes    59.65357
# no     40.34643
# Name: proportion, dtype: float64

# %%
df.isna().sum()
# Out:
# Date Published          0
# Rating                  0
# Max Rating              0
# Title                   0
# Author                  0
# Country                 0
# Review Body             0
# Type Of Traveller       0
# Seat Type               0
# Route                 437
# Date Flown              0
# Recommended             0
# Aircraft             1087
# Verified                0
# dtype: int64

# %% [markdown]
# <hr>

# %% [markdown]
# ### Čišćenje podataka - Route stupac
#
# Poglavlje u nastavku fokusira se na obradu nedostajućih podataka u stupcu `Route`<br>
#
# **TLDR**:
# - Normalizacija skraćenih ili netočnih naziva zračnih luka kako bi se osigurala konzistentnost i točnost podataka
# - Razdvajanje informacija iz stupca `Route` u tri nova stupca pod nazivom `From`, `Via` i `To`

# %%
# Prikaz NULL vrijednosti u stupcu Route
df[df['Route'].isna()]
# Out:
#      Date Published  Rating  Max Rating                               Title  \
# 836      2019-09-28     1.0        10.0             "Bitterly disappointed"
# 1823     2015-10-01     9.0        10.0  "cabin crew friendly and obliging"
# 1933     2015-06-13     9.0        10.0       Qatar Airways customer review
# 1934     2015-06-07     7.0        10.0       Qatar Airways customer review
# 1935     2015-06-06    10.0        10.0       Qatar Airways customer review
# ...             ...     ...         ...                                 ...
# 2364     2013-08-12     9.0        10.0       Qatar Airways customer review
# 2365     2013-08-06     7.0        10.0       Qatar Airways customer review
# 2366     2013-08-06     5.0        10.0       Qatar Airways customer review
# 2367     2013-08-06     7.0        10.0       Qatar Airways customer review
# 2368     2013-08-05     3.0        10.0       Qatar Airways customer review
#
#                 Author               Country  \
# 836          C Johnson        United Kingdom
# 1823      Mike Cameron        United Kingdom
# 1933         B Johnson          South Africa
# 1934            W Woon             Singapore
# 1935   Graham Williams        United Kingdom
# ...                ...                   ...
# 2364            R Nash             Australia
# 2365   Gamage Champika  United Arab Emirates
# 2366  Martin Fernandez                 Spain
# 2367    David Monteiro           Switzerland
# 2368         A Boorman        United Kingdom
#
#                                             Review Body Type Of Traveller  \
# 836    Kuwait to Manchester via Doha. Bitterly disap...          Business
# 1823  We flew London to Dubai through Doha, using Qa...    Couple Leisure
# 1933  For someone who has become used to the standar...          Business
# 1934  4 flight sectors altogether: SIN-DOH-LHR on 5 ...           Unknown
# 1935  I flew to Thailand for my honeymoon with Qatar...           Unknown
# ...                                                 ...               ...
# 2364  Flew first class CAI-DOH on QR503 on 8th Aug 2...           Unknown
# 2365  I took a flight to London on 17th July with my...           Unknown
# 2366  MAD-DOH-DXB and back. Boeing 777 in MAD-DOH se...           Unknown
# 2367  GVA-AUH A320. Good food but after the main mea...           Unknown
# 2368  London Heathrow - Yangon via Doha return. Firs...           Unknown
#
#            Seat Type Route      Date Flown Recommended    Aircraft  Verified
# 836      First Class   NaN  September 2019          no  Boeing 777       1.0
# 1823   Economy Class   NaN  September 2015         Yes  Boeing 777       0.0
# 1933  Business Class   NaN       June 2015         Yes         NaN       0.0
# 1934   Economy Class   NaN       June 2015          no         NaN       0.0
# 1935   Economy Class   NaN       June 2015         Yes         NaN       0.0
# ...              ...   ...             ...         ...         ...       ...
# 2364     First Class   NaN     August 2013         Yes         NaN       0.0
# 2365   Economy Class   NaN     August 2013          no         NaN       0.0
# 2366   Economy Class   NaN     August 2013          no         NaN       0.0
# 2367   Economy Class   NaN     August 2013          no         NaN       0.0
# 2368   Economy Class   NaN     August 2013          no         NaN       0.0
#
# [437 rows x 14 columns]

# %% [markdown]
# Zastupljeno je ukupno `437` zapisa koji imaju nedostajuće vrijednosti u stupcu `Route`

# %%
df['Route'].unique()
# Out:
# array(['Tokyo to London Heathrow via Doha', 'Doha to Montreal',
#        'Doha to Perth', ..., 'Milan-Doha and Doha-Guangzhou',
#        'Singapore-Doha-Johannesburg', 'MEL-DOH-LHR-DOH-MEL'], dtype=object)

# %%
df['Route'].value_counts()
# Out:
# Route
# Bangkok to Doha                      16
# Doha to Bangkok                      13
# Doha to London                       13
# London to Doha                       12
# LHR to BKK via DOH                    9
#                                      ..
# Milan to Auckland via Doha/Sydney     1
# Amman to Bangkok via Doha             1
# Lisbon to Doha                        1
# Doha to Dallas                        1
# MEL-DOH-LHR-DOH-MEL                   1
# Name: count, Length: 1380, dtype: int64

# %%
df['Route'].notna().sum()
# Out:
# 1930

# %% [markdown]
# #### Sanity Check!
#
# - Ukupan broj zapisa u podatkovnom skupu: 2367
# - Ukupan broj zapisa koji imaju neku vrijednost u `Route` stupcu: 1930
# - Ukupan broj zapisa koji imaju `NULL` vrijednost u `Route` stupcu: 437

# %%
# Broj zapisa koji sadrže riječ "to" u stupcu Route
(df['Route'].str.contains("to").sum())
# Out:
# 1920

# %%
# Razdvajanje stupca Route u stupce 'From' i 'To'
df[['From', 'To']] = df['Route'].str.split(' to ', expand=True)

# %%
df.sample(10)
# Out:
#      Date Published  Rating  Max Rating  \
# 210      2023-03-09     5.0        10.0
# 1363     2017-06-14    10.0        10.0
# 521      2021-10-31     8.0        10.0
# 1172     2018-03-17     7.0        10.0
# 1688     2016-02-26    10.0        10.0
# 1091     2018-08-10     9.0        10.0
# 663      2020-09-02     1.0        10.0
# 2196     2014-05-08     7.0        10.0
# 181      2023-04-24     3.0        10.0
# 1408     2017-04-18     9.0        10.0
#
#                                             Title            Author  \
# 210        "not responsible for the compensation"        Yizhong Gu
# 1363              "this trip was the best so far"    David Graubard
# 521            "Perfect, can't say anything else"     Mike Andrésen
# 1172  "Qatar A380 business has to be my favorite"            D Webb
# 1688                   "really enjoyed my flight"     Juraj Krajcik
# 1091               "always had excellent service"  Dilys Anne Kevan
# 663   "connecting airBaltic flight was cancelled"          S Marlen
# 2196                Qatar Airways customer review          D Walker
# 181               "was against their regulations"           T Layne
# 1408                "services are very efficient"         S Valeiro
#
#              Country                                        Review Body  \
# 210    United States    Our tickets from JFK to MLE were changed fro...
# 1363   United States  ✅ Verified Review |  May 12, flew ORD-DOH-DEL ...
# 521           Sweden    Perfect, can't say anything else. Smooth che...
# 1172  United Kingdom    Return flight to Copenhagen via Doha. Really...
# 1688        Slovakia  Budapest to Bangkok via Doha. I really enjoyed...
# 1091           Spain    Melbourne to Madrid via Doha. Between Melbou...
# 663        Australia    I bought a ticket from Melbourne to Tallin w...
# 2196  United Kingdom  Very good service providing the price. Staff a...
# 181    United States    I purchased two tickets to ensure I have com...
# 1408     Philippines  ✅ Verified Review |  Flew both Qatar Airways B...
#
#      Type Of Traveller       Seat Type                             Route  \
# 210     Couple Leisure  Business Class                  New York to Diha
# 1363      Solo Leisure  Business Class         Chicago to Delhi via Doha
# 521       Solo Leisure  Business Class                 Stockholm to Doha
# 1172      Solo Leisure  Business Class    Bangkok to Copenhagen via Doha
# 1688    Couple Leisure   Economy Class                BUD to BKK via DOH
# 1091      Solo Leisure   Economy Class      Melbourne to Madrid via Doha
# 663       Solo Leisure   Economy Class              Melbourne to Tallinn
# 2196           Unknown   Economy Class                               NaN
# 181       Solo Leisure   Economy Class  Atlanta to Kuala Lumpur via Doha
# 1408          Business   Economy Class         Geneva to Manila via Doha
#
#           Date Flown Recommended                    Aircraft  Verified  \
# 210    February 2023          no                  Boeing 777       1.0
# 1363        May 2017         Yes  Boeing 777-300, Boeing 787       1.0
# 521     October 2021         Yes                Boeing 787-8       1.0
# 1172      March 2018          no           A380 / Boeing 787       1.0
# 1688   December 2015         Yes                        A380       0.0
# 1091     August 2018         Yes                    A380-800       1.0
# 663   September 2020          no                         NaN       1.0
# 2196        May 2014          no                         NaN       0.0
# 181       March 2023          no            Boeing 777-300ER       1.0
# 1408      April 2017         Yes                         NaN       1.0
#
#            From                     To
# 210    New York                   Diha
# 1363    Chicago         Delhi via Doha
# 521   Stockholm                   Doha
# 1172    Bangkok    Copenhagen via Doha
# 1688        BUD            BKK via DOH
# 1091  Melbourne        Madrid via Doha
# 663   Melbourne                Tallinn
# 2196        NaN                    NaN
# 181     Atlanta  Kuala Lumpur via Doha
# 1408     Geneva        Manila via Doha

# %%
# Not-Null vrijednost u 'From' stupcu
df['From'].notna().sum()
# Out:
# 1930

# %% [markdown]
# Iz navedenog možemo uočiti da smo uspješno napravili dva nova stupca, `From` i `To` stupac, pri čemu su oba podijeljena prema ključnoj riječi "to". <br>
# Nadalje, iz stupca `To` potrebno je napraviti novi stupac pod nazivom `Via`, čije ćemo podatke izvući iz tog istog stupca.

# %%
# Not-Null vrijednosti u 'To' stupcu
df['To'].notna().sum()
# Out:
# 1920

# %% [markdown]
# Budući da je u stupcu `To` popunjeno `1920` zapisa, još uvijek preostaje `10` zapisa koji su prazni.

# %%
df[['Author', 'Route']][df['From'].notna() & df['To'].isna()]
# Out:
#              Author                          Route
# 1570      B Nalikov                     doh TO sof
# 1911    Tom Osborne                    LHR-DOH-BKK
# 1913  Denzil Bourne                SIN-LHR via DOH
# 1914  Denzil Bourne                LHR-SIN via DOH
# 1921       R Clarke                    MEL-DOH-BAH
# 1927    M LaPrairie                        IAD-DOH
# 1928   B Wijesinghe            IAD-DOH-CMB-DOH-IAD
# 1930      F Bertoni  Milan-Doha and Doha-Guangzhou
# 1931       Rob Wood    Singapore-Doha-Johannesburg
# 1932      Dan James            MEL-DOH-LHR-DOH-MEL

# %% [markdown]
# Za `10` iznad ispisanih zapisa ručno ćemo ažurirati podatke u istima.

# %%
condition = df['Author'] == 'Tom Osborne'

df.loc[condition, 'From'] = 'Heathrow'
df.loc[condition, 'To'] = 'Suvarnabhumi'

# %%
condition = df['Author'] == 'Denzil Bourne'

df.loc[condition, 'From'] = 'Singapore'
df.loc[condition, 'To'] = 'Heathrow'

# %%
condition = df['Author'] == 'B Nalikov'

df.loc[condition, 'From'] = 'Doha'
df.loc[condition, 'To'] = 'Sofia'

# %%
condition = df['Author'] == 'R Clarke'

df.loc[condition, 'From'] = 'Melbourne'
df.loc[condition, 'To'] = 'Bahrain'

# %%
condition = df['Author'] == 'M LaPrairie'

df.loc[condition, 'From'] = 'Dulles'
df.loc[condition, 'To'] = 'Doha'

# %%
condition = df['Author'] == 'B Wijesinghe'

df.loc[condition, 'From'] = 'Dulles'
df.loc[condition, 'To'] = 'Bandaranaike'

# %%
condition = df['Author'] == 'F Bertoni'

df.loc[condition, 'From'] = 'Milan'
df.loc[condition, 'To'] = 'Guangzhou'

# %%
condition = df['Author'] == 'Rob Wood'

df.loc[condition, 'From'] = 'Singapore'
df.loc[condition, 'To'] = 'Johannesburg'

# %%
condition = df['Author'] == 'Dan James'

df.loc[condition, 'From'] = 'Melbourne'
df.loc[condition, 'To'] = 'Heathrow'

# %%
df.isna().sum()
# Out:
# Date Published          0
# Rating                  0
# Max Rating              0
# Title                   0
# Author                  0
# Country                 0
# Review Body             0
# Type Of Traveller       0
# Seat Type               0
# Route                 437
# Date Flown              0
# Recommended             0
# Aircraft             1087
# Verified                0
# From                  425
# To                    425
# dtype: int64

# %%
df['From'].unique()
# Out:
# array(['Tokyo', 'Doha', 'Auckland', 'New Delhi', 'Dusseldorf',
#        'Frankfurt', 'New York', 'Chicago', 'Nice', 'Penang', 'Ahmedabad',
#        'Tbilisi', 'Spain', 'London', 'Beirut', 'Gatwick', 'Bali',
#        'Copenhagen', 'Dallas Ft Worth', 'Manchester', 'Athens',
#        'Ho Chi Minh', 'Düsseldorf', 'Bangkok', 'Ho Chi Minh City',
#        'Kuwait', 'Dubai', 'Milan', 'Brisbane', 'Mahé', 'Lusaka',
#        'Istanbul', 'Melbourne', 'Seattle', 'Brussels', 'Perth',
#        'Denpasar', 'Stockholm', 'Riyadh', 'Zurich', 'Singapore', 'doh',
#        'Oslo', 'Kathmandu', 'Paris', 'Vienna', 'Colombo',
#        'London Heathrow', 'Amsterdam', 'Washington', 'Jakarta',
#        'Abu Dhabi', 'Entebbe', 'Johannesburg', 'Sydney', 'Philadelphia',
#        'Mumbai', 'Warsaw', 'Edinburgh', 'Islamabad', 'Geneva', 'Montreal',
#        'Dallas', 'Hanoi', 'Maputo', 'Rome', 'Jarkata', 'Bucharest',
#        'Phuket', 'Dublin', 'Manila', 'Harare', 'New York JFK', 'Boston',
#        'Los Angeles', 'Madrid', 'Tehran', 'Sofia', 'Lagos', 'Prague',
#        'Delhi', 'Franfurt', 'Nairobi', 'Thailand', 'Atlanta', 'São Paulo',
#        'Ho chi Minh City', 'Algiers', 'Munich', 'Barcelona', 'Sharjah',
#        'Miami', 'Kuala Lumpur', 'San Francisco', 'Zagreb', 'Brisibane',
#        'Cochin', 'Cape Town', 'Kochi', 'madrid', 'Ankara', 'Kigali',
#        'Erbil', 'Maldives', 'Toronto', 'Hyderabad', 'Lagos, Nigeria',
#        'Tunis', 'Madrid ', 'Cairo', 'Male', 'Chennai', 'Bodrum ',
#        'Malaga', 'Chengdu', 'Cebu', 'Belgrade', 'Dammam',
#        'Thiruvananthapuram', 'Adelaide', 'Hong Kong', 'Dallas Fort Worth',
#        'Kozikhode', 'Houston', 'Helsinki', 'Zanzibar', 'Casablanca',
#        'Dhaka', 'Kyiv', 'Berlin', 'Najaf', 'Lahore', 'Seoul', 'Muscat',
#        'Mogadishu', 'Zvartnots', 'Krabi', 'Sulaymaniyah', 'Tblisi',
#        'Lisbon', 'Amman', 'Bangalore', 'Amritsar', 'Yangon', 'Budapest',
#        'Birmingham', 'Dulles', 'Pisa', 'Venice', 'Goa', 'Heathrow',
#        'Cardiff', 'Mahe', 'Kolkata', nan, 'Dar es Salaam', 'Kiev',
#        'Calicut', 'Moscow', 'Paris CDG', 'DEL', 'Doha ', 'Incheon',
#        'Gothenburg', 'Sarajevo', 'Clark', 'London ', 'Canberra',
#        'Mahé, Seychelles', 'Bombay', 'Nagpur', 'Shanghai', 'Karachi',
#        'Marrakech', 'Berlin Tegel', 'BKK', 'Durban', 'Baku', 'MAA',
#        'Salalah', 'Berlin ', 'London Heatrhow', 'MAD', 'Phnom Penh',
#        'Luxor', 'TXL', 'CRK', 'Washington DC', 'BCN', 'DOH', 'KUL', 'DPS',
#        'MNL', 'LHR', 'Medina', 'Taif', 'CPH', 'EZE', 'MAN', 'EDI', 'SVO',
#        'MEL', 'TUN', 'OSL', 'PHL', 'PER', 'PNH', 'AMM', 'VCE', 'ARN',
#        'CPT', 'IAH', 'SYD', 'HKT', 'AMS', 'AUH', 'JNB', 'ATL', 'DXB',
#        'JFK', 'SIN', 'HAN', 'DFW', 'HEL', 'CMB', 'PVG', 'MUC', 'SGN',
#        'IKA', 'BOM', 'LAX', 'BRU', 'ADL', 'KHI', 'LAS', 'ZAG', 'ATH',
#        'ICN', 'BEY', 'SOF', 'SAO', 'FRA', 'TIF', 'ZRH', 'WAW', 'PSA',
#        'MCT', 'BOS', 'CDG', 'CGK', 'IAD', 'HKG', 'BHX', 'ISB', 'GRU',
#        'BLR', 'KIX', 'JED', 'BUD', 'PEN', 'RUH', 'GYD', 'manchester',
#        'MXP', 'HND', 'ORD', 'HBE', 'NBO', 'NRT', 'KTM', 'SAW', 'FCO',
#        'KWI', 'cape town', 'DWC', 'CAI', 'NYC', 'Dar es Salam', 'COK',
#        'Jinnah Int', 'Dubai DWC', 'KUala Lumpur'], dtype=object)

# %%
df['To'].unique()
# Out:
# array(['London Heathrow via Doha', 'Montreal', 'Perth', 'London Heathrow',
#        'Doha', 'London', 'San Francisco', 'Kilimanjaro via Doha',
#        'Melbourne via Doha', 'Johannesburg via Doha', 'Dubai via Doha',
#        'Adelaide', 'Doha via Phuket', 'Detroit via Doha',
#        'Singapore via Doha', 'Perth via Doha', 'Auckland via Doha',
#        'Erbil via Doha', 'London via Doha', 'Goa', 'Brussels',
#        'Adelaide via Doha', 'Kolkata via Doha', 'Bangkok via Doha',
#        'Bangkok', 'Frankfurt', 'Sydney', 'Manchester via Doha',
#        'Warsaw via Doha', 'Tokyo via Doha', 'Delhi via Doha',
#        'Kuala Lumpur via Doha', 'Salalah via Doha', 'Amsterdam via Doha',
#        'Johannesburg', 'Tbilisi via Doha', 'Lyon via Doha', 'Denpasar',
#        'Washington', 'Luanda via Doha', 'Lusaka via Doha',
#        'Milan via Doha', 'kwi', 'Sao Paulo via Doha', 'Chicago',
#        'Brussels via Doha', 'Seattle', 'Kuwait via Doha', 'Singapore',
#        'Gatwick via Doha', 'Denpasar Bali via Doha', 'Cape Town via Doha',
#        'Brisbane via Doha', 'Kathmanda via Doha', 'Muscat via Doha',
#        'Athens via Doha', 'Vienna via Doha', 'Rome via Doha', 'Bahrain',
#        'Kuwait', 'Colombo', 'Abu Dhabi via Doha', 'Auckland', 'Istanbul',
#        'Barcelona via Doha', 'Paris via Doha', 'Frankfurt via Doha',
#        'Tokyo', 'Phuket via Doha', 'Edinburgh via Doha', 'Kochi via Doha',
#        'Colombo via Doha', 'Tehran via Doha', 'Mumbai', 'Zurich via Doha',
#        'Berlin via Doha', 'New York JFK', 'Windhoek via Doha',
#        'Cape Town', 'Philadelphia via Doha', 'Riyadh via Doha',
#        'Johannesburg via Dohs', 'Denpasar via Doha', 'Warsaw',
#        'Jakarta via Doha', 'Lagos via Doha', 'Cochin via Doha',
#        'Montreal via Doha', 'Baghdad via Doha', 'Bali via Doha',
#        'Chicago via Doha', 'Dhaka via Doha', 'Bucharest via Doha',
#        'Hanoi', 'Dallas via Doha', 'Sydney via Doha', 'Manila via Doha',
#        'Ord', 'Istanbul via Doha', 'Phuket', 'Dublin via Doha',
#        'Zagreb via Doha', 'Madrid via Doha', 'São Paulo via Doha',
#        'Nairobi via Doha', 'Goa via Doha', 'Hamad', 'Diha',
#        'Bangalore via Doha', 'sharjah via dona', 'Male',
#        'Islamabad via Doha', 'Ho Chi Minh via Doha', 'Prague via Doha',
#        'Toronto via Montreal & Doha', 'Karachi via Doha', 'Male via Doha',
#        'Munich via Doha', 'Ho Chi Minh City', 'Oslo', 'Boston',
#        'Dammam via Doha', 'Lahore', 'Miami via Doha',
#        'Hyderabad via Doha', 'Philadelphia', ' Doha', 'Mactan via Doha',
#        'Cairo via Doha', 'Cebu via Doha', 'Budapest via Doha', 'Madrid',
#        'Atlanta via Doha', 'Helsinki via Doha', 'Miami', 'Melbourne',
#        'London Gatwick via Doha', 'Beirut', 'Brisbane via Doha / Perth',
#        'Jakarta', 'Paris', 'Washington via Doha',
#        'London Heathrow via Doha, Qatar', 'Lahore via Doha',
#        'Entebbe via Doha', 'New York', 'Kuala Lumpur',
#        'San Diego via Doha', 'Hong Kong via Doha', 'Nagpur via Doha',
#        'Los Angeles via Doha', 'New York via Doha', 'Entebbe',
#        'Durban via Doha', 'Chennai via Doha', 'Durban',
#        'Ho Chi Minh City via Doha', 'Amman via Doha & Hong Kong',
#        'Atlanta', 'Washington DC via Doha',
#        'Kozhikode via Montreal / Doha', 'Ahmedabad', 'Stockholm via Doha',
#        'Doha via Manila', 'Kathmandu via Doha', 'Boston via Doha',
#        'Kolkata', 'Beirut via Doha', 'Copenhagen via Doha',
#        "Chicago O'Hare via Doha", 'Seattle via Doha', 'Houston via Doha',
#        'Mumbai via Doha', 'Sialkot via Doha', 'Los Angeles',
#        'Auckland via Brisbane', 'Medina', 'Baku', 'Doha via Dubai',
#        'Doha via Brussels', 'Moscow via Doha', 'Cape town via Doha',
#        'Dubai', 'Casablanca via Doha', 'Sao Paulo', 'Lahore VIA \\DOHA',
#        'Bucharest via Dha', 'Larnaca via Doha', 'Clark',
#        'Jeddah via Doha', 'Warsaw via doha',
#        'Copenhagen via Entebbe, Doha', 'San Francisco via Doha',
#        'Maldives via Doha', 'Keflavik via Copenhagen', 'Basra via Doha',
#        'Yerevan via Doha', 'Bengaluru', 'Dhaka',
#        'Sao Paulo GRU via London', 'Doha via Adelaide', 'Islamabad',
#        'Tokyo Narita via Doha', 'Zanzibar via Doha',
#        'Bermuda via New York', 'Manchester', 'Amman via Doha',
#        'Washington Dulles via Doha', 'Seoul Incheon via Doha', 'Tallinn',
#        'Dallas Ft Worth via Doha', 'Dallas', 'Auckland via Doha/Sydney',
#        'Nairobi', 'Manila', 'Vancouver via Doha', 'Delhi via Delhi',
#        'Warsaw via Qatar', 'Cochi', 'Danang via Doha', 'Oslo via Doha',
#        'Najaf via Doha', 'St Petersburg via Doha', 'Da Nang via Doha',
#        'Doha via London', 'Kyiv via Doha', 'Shanghai via Doha', 'Karachi',
#        'Athens', 'Antalya via Doha', 'Sofia via Doha', 'Bombay via Doha',
#        'Kigali', 'Amsterdam', 'Gatwick', 'Phnom Penh via Doha',
#        'Barcelona', 'Gothenburg via Doha', 'Hong Kong',
#        'Langkawi via Doha', 'Penang via Doha', 'Birmingham via Doha',
#        'New York JFK via Doha', 'Multan via Doha', nan, 'Seoul via Doha',
#        'Venice via Doha', 'Nice via Doha', 'Tunis via Doha', 'Amman',
#        'Ankara via Doha', 'Calicut', 'Munich', 'BCN via DOH',
#        'Amritsar via Doha', 'Stockholm', 'Rio de Janeiro via Doha',
#        ' Gatwick via Doha', 'Edinburgh', 'Dar Es Salaam via Doha',
#        'Colombo via Montreal / Doha', 'Copenhagen', 'Hanoi via Doha',
#        'Geneva', 'Trivandrum via Doha', 'Geneva via Doha', 'Cardiff',
#        'Casablanca', 'Hi Chi Minh City via Doha',
#        'London via Sydney / Doha', 'Doha via Bangkok', 'Cardiff via Doha',
#        'Muscat', 'Milan', 'Doha via Jakarta',
#        'Moscow via Adelaide / Doha', 'Clark via Doha', 'Doha via Sydney',
#        'Kigali via Doha', 'Dublin  via Doha', 'Paris CDG',
#        'Kuala Lumpur via Baku / Doha', 'Chiang Mai via Doha', 'Kathmandu',
#        'Kigali via Doha, Entebbe', 'Houston', 'Incheon via Doha', 'DOH',
#        'Guangzhou', 'Chennai return via Doha', 'Budapest', 'JFK via DOH',
#        'Kiev', 'Kochi', 'Bali', 'Hyderabad  via Doha',
#        'Belgrade via Doha', 'Melbourne Australia via Doha', 'Yangon',
#        'SIN via DOH', 'FRA via DOH', 'Tblisi', 'Chongqing via Dubai',
#        'Riyadh', 'Khartoum via Doha', 'Thiruvananthapuram via Doha',
#        'Kozhikode via Doha', 'DPS via DOH', 'Pnom Penh', 'MAD via DOH',
#        'Baku via Doha', 'BKK via DOH', 'JFK', 'CPH via DOH', 'Alexandria',
#        'LHR via DOH', 'DXB via DOH', 'Bangkok via doha', 'Taif via Doha',
#        'EDI via DOH', 'CMB via DOH', 'BOM via DOH', 'KUL via DOH',
#        'CMN via DOH', 'ADL via DOH', 'NRT via DOH', 'SGN', 'MUC via  DOH',
#        'KTM via DOH', 'AUH via DOH', 'GOI via DOH', 'HKT via DOH', 'COK',
#        'CCU', 'BRUvia DOH', 'PER via DOH', 'ISB via DOH', 'KWI via DOH',
#        'DWC', 'FRA', 'MCT via DOH', 'AMM via DOH', 'BKK', 'DEL via DOH',
#        'MEL via DOH', 'JRO via DOH', 'CAI via DOH', 'KUL', 'CDG via DOH',
#        'FCO via SIN', 'PNH', 'MAN via DOH', 'ATL via DOH', 'VCE via DOH',
#        'JNB via DOH', 'CGK via DOH', 'PHL', 'KHI via DOH', 'ATH via DOH',
#        'FCO via DOH', 'HKG via DOH', 'TXL via DOH', 'DAR via DOH',
#        'MNL via DOH', 'LHE via DOH', 'Sofia', 'LHR', 'MLE via DOH',
#        'CPH via BKK / DOH', 'GVA via DOH', 'DWC via DOH', 'ZRH via DOH',
#        'WAW via DOH', 'CDG', 'ORD', 'CPT via DOH', 'LAX', 'HAN via DOH',
#        'PVG via DOH', 'AKL via DOH', 'SYD', 'COK via DOH', 'HYD via DOH',
#        'MUC via DOH', 'CPH via DOA', 'ICN via DOH', 'CPH via BKK and DOH',
#        'IST via DOH', 'SIN', 'BRU via DOH', 'MAN', 'IAD via DOH',
#        'SYD via DXB', 'HKG', 'LHR via BKK/DOH', 'DUR via DOH/JNB',
#        'BHX via BRU', 'BEG via DOH', 'CNB via DOH', 'HAN', 'VIE', 'MEL',
#        'OSL via DOH', 'MCO', 'SYD via DOH', 'CMB', 'MAN via DSOH',
#        'SGN via DOH', 'DFW via DOH', 'DOH via BKK', 'EDI', 'goa via doha',
#        'DAC via DOH', 'DXB', 'AMS', 'SIN via LHR/DOH', 'YUL via DOH',
#        'IAD', 'SNG via DOH', 'HND via DOH', 'HAN via DOH/BKK',
#        'AMD via DOH', 'AMS via DOH', 'MCT', 'LOS via DOH',
#        'NBO via BKK, DOH', 'SYZ via DOH', 'BKK via Doha', 'PER',
#        'ARN via DOH', 'Bangalore via DOH', 'Colombo via DOH',
#        'GYD via DOH', 'HAN via DOH and BKK', 'Amritsar via DOH',
#        'STO via DOH', 'KUL via Doha', 'Perth via DOH', 'CPH via BKK/DOH',
#        'Melbourne via DOH', 'Istanbul via DOH', 'brussels via doha',
#        'Athens via DOH', 'Madrid via DOH', 'Riyadh via DOH',
#        'Zagreb via DOH', 'Bangkok via DOH', 'RGN via DOH',
#        'Venice via DOH', 'Philadelphia via DOH', 'Sao Paulo via DOH',
#        'Frankfurt via DOH', 'CDG via Doha', 'Brisbane',
#        'Edinburgh via DOH', 'Shanghai via DOH', 'Singapore via DOH',
#        'Doha airport', 'Vienna', 'New York via DOH',
#        'Istanbul (SAW) via Doha', 'Johanesburg via Doha', 'Suvarnabhumi',
#        'MIA via DOH', 'Heathrow', 'BKK via BKK-DOH-CPH//DOH', 'EZE',
#        'Bandaranaike'], dtype=object)

# %%
# RegEx pattern za izdvajanje teksta nakon 'via'
pattern = r'via\s+(.*)'

# Izdvajanje teksta nakon 'via' te kreiranje novog stupca pod nazivom 'Via'
df['Via'] = df['Route'].str.extract(pattern, expand=False)

# %%
df.sample(10)
# Out:
#      Date Published  Rating  Max Rating                                Title  \
# 1337     2017-07-21     4.0        10.0            "food was rather limited"
# 2215     2014-04-08     8.0        10.0        Qatar Airways customer review
# 637      2020-11-28     4.0        10.0          "The service was exemplary"
# 2311     2013-11-28    10.0        10.0        Qatar Airways customer review
# 1644     2016-04-23    10.0        10.0     "fabulous for long haul flights"
# 556      2021-08-03     1.0        10.0  "ask for some form of compensation"
# 61       2023-10-25     5.0        10.0               "issues on the ground"
# 348      2022-08-18     6.0        10.0  "raised my hand when he skipped us"
# 1077     2018-09-02    10.0        10.0    "crew is professional, attentive"
# 612      2021-02-07    10.0        10.0         "Excellent service provided"
#
#               Author         Country  \
# 1337       L Geazler     Switzerland
# 2215        J Howsam  United Kingdom
# 637           T Kane       Australia
# 2311        R Barton  United Kingdom
# 1644      Sal Rogers       Australia
# 556           L Yang   United States
# 61    Michael Schade         Germany
# 348        R Mardunu           Spain
# 1077       U Colombo    South Africa
# 612       Ikbal Gill           India
#
#                                             Review Body Type Of Traveller  \
# 1337  ✅ Verified Review |  Adelaide to Zurich via Do...          Business
# 2215  Economy - LHR to Melbourne. Boeing 777-200/300...           Unknown
# 637     We flew Sydney-Doha-London business class. W...    Couple Leisure
# 2311  MAN-DOH-BKK-HAN-SGN-DOH-MAN. Really impressed ...           Unknown
# 1644  ✅ Verified Review |  Melbourne to Rome via Doh...          Business
# 556     Nairobi - Doha - Boston, with a relatively s...      Solo Leisure
# 61       Check in at BKK airport swift and friendly,...      Solo Leisure
# 348     I and my son boarded Qatar Airways from Ente...    Family Leisure
# 1077    Milan to Cape Town via Doha. You have to be ...      Solo Leisure
# 612     Excellent service and so kind and nice and p...          Business
#
#            Seat Type                         Route     Date Flown Recommended  \
# 1337  Business Class   Adelaide to Zurich via Doha      July 2017          no
# 2215   Economy Class                           NaN     April 2014         Yes
# 637   Business Class     Sydney to London via Doha   October 2020          no
# 2311   Economy Class                           NaN  November 2013         Yes
# 1644  Business Class            MEL to FCO via DOH     April 2016         Yes
# 556    Economy Class    Nairobi to Boston via Doha      July 2021          no
# 61    Business Class  Bangkok to Brussels via Doha   October 2023          no
# 348    Economy Class    Entebbe to Madrid via Doha    August 2022          no
# 1077  Business Class   Milan to Cape Town via Doha    August 2018         Yes
# 612    Economy Class               Algiers to Doha  February 2021         Yes
#
#                Aircraft  Verified      From                  To   Via
# 1337               A350       1.0  Adelaide     Zurich via Doha  Doha
# 2215                NaN       0.0       NaN                 NaN   NaN
# 637          Boeing 777       1.0    Sydney     London via Doha  Doha
# 2311                NaN       0.0       NaN                 NaN   NaN
# 1644  Boeing 777-300 ER       1.0       MEL         FCO via DOH   DOH
# 556                 NaN       1.0   Nairobi     Boston via Doha  Doha
# 61    A380 / Boeing 789       1.0   Bangkok   Brussels via Doha  Doha
# 348            A330-300       1.0   Entebbe     Madrid via Doha  Doha
# 1077   Boeing-777 / 787       1.0     Milan  Cape Town via Doha  Doha
# 612                 NaN       1.0   Algiers                Doha   NaN

# %%
df['To'] = df['To'].str.split(' via ').str[0]

df
# Out:
#      Date Published  Rating  Max Rating  \
# 0        2024-03-02     1.0        10.0
# 1        2024-02-29     1.0        10.0
# 2        2024-02-29     1.0        10.0
# 3        2024-02-25    10.0        10.0
# 4        2024-02-22     7.0        10.0
# ...             ...     ...         ...
# 2364     2013-08-12     9.0        10.0
# 2365     2013-08-06     7.0        10.0
# 2366     2013-08-06     5.0        10.0
# 2367     2013-08-06     7.0        10.0
# 2368     2013-08-05     3.0        10.0
#
#                                       Title            Author  \
# 0                “marred by inconveniences”           Mary Le
# 1                   "seat wouldn't stay up"     Brian English
# 2     "no attempt to address our complaint"     Wayne Burgess
# 3             “I hope they update the A380”  Alwaleed Althani
# 4                "I’d rate them maybe 7/10"         W Warnock
# ...                                     ...               ...
# 2364          Qatar Airways customer review            R Nash
# 2365          Qatar Airways customer review   Gamage Champika
# 2366          Qatar Airways customer review  Martin Fernandez
# 2367          Qatar Airways customer review    David Monteiro
# 2368          Qatar Airways customer review         A Boorman
#
#                    Country                                        Review Body  \
# 0           United Kingdom   The delay of my flight from Haneda to Doha ca...
# 1                   Canada    They convinced me that I needed to pay $1500...
# 2                Australia    I have sent 5 emails and have only received ...
# 3                    Qatar   We flew on probably the first A380 the airlin...
# 4           United Kingdom    Service was ok, pretty good on my aisle and ...
# ...                    ...                                                ...
# 2364             Australia  Flew first class CAI-DOH on QR503 on 8th Aug 2...
# 2365  United Arab Emirates  I took a flight to London on 17th July with my...
# 2366                 Spain  MAD-DOH-DXB and back. Boeing 777 in MAD-DOH se...
# 2367           Switzerland  GVA-AUH A320. Good food but after the main mea...
# 2368        United Kingdom  London Heathrow - Yangon via Doha return. Firs...
#
#      Type Of Traveller       Seat Type                              Route  \
# 0         Solo Leisure   Economy Class  Tokyo to London Heathrow via Doha
# 1       Couple Leisure  Business Class                   Doha to Montreal
# 2             Business   Economy Class                      Doha to Perth
# 3       Couple Leisure     First Class            Doha to London Heathrow
# 4       Couple Leisure  Business Class                   Auckland to Doha
# ...                ...             ...                                ...
# 2364           Unknown     First Class                                NaN
# 2365           Unknown   Economy Class                                NaN
# 2366           Unknown   Economy Class                                NaN
# 2367           Unknown   Economy Class                                NaN
# 2368           Unknown   Economy Class                                NaN
#
#          Date Flown Recommended  Aircraft  Verified      From  \
# 0        March 2024          no       NaN       0.0     Tokyo
# 1     February 2024          no       NaN       1.0      Doha
# 2     November 2023          no      A380       1.0      Doha
# 3     February 2024         Yes  A380-800       1.0      Doha
# 4     February 2024          no      A350       1.0  Auckland
# ...             ...         ...       ...       ...       ...
# 2364    August 2013         Yes       NaN       0.0       NaN
# 2365    August 2013          no       NaN       0.0       NaN
# 2366    August 2013          no       NaN       0.0       NaN
# 2367    August 2013          no       NaN       0.0       NaN
# 2368    August 2013          no       NaN       0.0       NaN
#
#                    To   Via
# 0     London Heathrow  Doha
# 1            Montreal   NaN
# 2               Perth   NaN
# 3     London Heathrow   NaN
# 4                Doha   NaN
# ...               ...   ...
# 2364              NaN   NaN
# 2365              NaN   NaN
# 2366              NaN   NaN
# 2367              NaN   NaN
# 2368              NaN   NaN
#
# [2367 rows x 17 columns]

# %%
df.sample(10)
# Out:
#      Date Published  Rating  Max Rating                            Title  \
# 328      2022-09-07    10.0        10.0            "surprise was so big"
# 560      2021-07-20    10.0        10.0     "can recommend this airline"
# 2281     2014-01-13     6.0        10.0    Qatar Airways customer review
# 1339     2017-07-20     8.0        10.0  "experience been quite amazing"
# 1452     2017-02-20     5.0        10.0     "there is no USB connection"
# 1134     2018-05-15     7.0        10.0         "Boeing 787 was cramped"
# 836      2019-09-28     1.0        10.0          "Bitterly disappointed"
# 1647     2016-04-13     6.0        10.0      "some economies being made"
# 1540     2016-09-28     5.0        10.0    "the food service was meagre"
# 716      2020-03-22    10.0        10.0            "really good service"
#
#                Author         Country  \
# 328    Elena Gheorghe         Romania
# 560      Ronald Kakas        Slovakia
# 2281    Philip Mcdaid       Australia
# 1339       P Tarnello           Italy
# 1452    Zdenek Sychra  Czech Republic
# 1134   Dominic Grundy       Australia
# 836         C Johnson  United Kingdom
# 1647         S Thomas           Qatar
# 1540        G Schumer   United States
# 716   Bibin Tharappel           India
#
#                                             Review Body Type Of Traveller  \
# 328    New York to Bucharest via Doha. On August 27,...    Couple Leisure
# 560     This was not my first experience with Qatar ...      Solo Leisure
# 2281  Munich-Doha-Perth. Munich to Doha on pretty em...           Unknown
# 1339  ✅ Verified Review |  Venice to Male via Doha. ...    Family Leisure
# 1452  ✅ Verified Review |  Krabi to Munich via Doha....    Couple Leisure
# 1134    Adelaide to Manchester via Doha. Two flights...      Solo Leisure
# 836    Kuwait to Manchester via Doha. Bitterly disap...          Business
# 1647  ✅ Verified Review |  Qatar Airways are still u...          Business
# 1540  ✅ Verified Review |  Los Angeles to Johannesbu...    Couple Leisure
# 716     From Doha to Cochi. Qatar Airways Economy cl...      Solo Leisure
#
#            Seat Type                            Route      Date Flown  \
# 328    Economy Class   New York to Bucharest via Doha     August 2022
# 560    Economy Class       Bangkok to Vienna via Doha       July 2021
# 2281   Economy Class                              NaN    January 2014
# 1339   Economy Class          Venice to Male via Doha   February 2017
# 1452   Economy Class         Krabi to Munich via Doha   February 2017
# 1134   Economy Class  Adelaide to Manchester via Doha        May 2018
# 836      First Class                              NaN  September 2019
# 1647  Business Class                       DOH to MAN      April 2016
# 1540   Economy Class               LAX to JNB via DOH  September 2016
# 716    Economy Class                    Doha to Cochi      March 2020
#
#      Recommended             Aircraft  Verified      From          To   Via
# 328          Yes                  NaN       0.0  New York   Bucharest  Doha
# 560          Yes                  NaN       1.0   Bangkok      Vienna  Doha
# 2281          no                  NaN       0.0       NaN         NaN   NaN
# 1339         Yes  A330-200 / A330-300       1.0    Venice        Male  Doha
# 1452          no                 A330       1.0     Krabi      Munich  Doha
# 1134          no             A350-900       1.0  Adelaide  Manchester  Doha
# 836           no           Boeing 777       1.0       NaN         NaN   NaN
# 1647          no             A330-200       1.0       DOH         MAN   NaN
# 1540          no     Boeing 777-200LR       1.0       LAX         JNB   DOH
# 716          Yes                  NaN       0.0      Doha       Cochi   NaN

# %%
df['Via'].unique()
# Out:
# array(['Doha', nan, 'Phuket', 'Dohs', 'dona', 'Montreal & Doha',
#        'Doha / Perth', 'Doha, Qatar', 'Doha & Hong Kong',
#        'Montreal / Doha', 'Manila', 'Brisbane', 'Dubai', 'Brussels',
#        'Dha', 'doha', 'Entebbe, Doha', 'Copenhagen', 'London', 'Adelaide',
#        'New York', 'Doha/Sydney', 'Delhi', 'Qatar', 'DOH',
#        'Sydney / Doha', 'Bangkok', 'Jakarta', 'Adelaide / Doha', 'Sydney',
#        'Baku / Doha', 'Doha, Entebbe', 'SIN', 'BKK / DOH', 'DOA',
#        'BKK and DOH', 'DXB', 'BKK/DOH', 'DOH/JNB', 'BRU', 'DSOH', 'BKK',
#        'LHR/DOH', 'DOH/BKK', 'BKK, DOH', 'DOH and BKK',
#        'BKK-DOH-CPH//DOH'], dtype=object)

# %%
df[['From', "To", 'Via']].isna().sum()
# Out:
# From     425
# To       425
# Via     1010
# dtype: int64

# %%
df.isna().sum()
# Out:
# Date Published          0
# Rating                  0
# Max Rating              0
# Title                   0
# Author                  0
# Country                 0
# Review Body             0
# Type Of Traveller       0
# Seat Type               0
# Route                 437
# Date Flown              0
# Recommended             0
# Aircraft             1087
# Verified                0
# From                  425
# To                    425
# Via                  1010
# dtype: int64

# %%
# Not-Null vrijednosti u 'Via' stupcu
df['Via'].notna().sum()
# Out:
# 1357

# %%
# Pretvaranje `Route` stupca u tip String
df['Route'] = df['Route'].astype(str)

# Filtriranje zapisa koji ne sadrže tekst `Via` u stupcu `Route`
filtered_df = df[~df['Route'].str.contains('via')]

# %%
# Ažuriranje zapisa koji ne sadrže "Via" u stupcu "Route" sa "Direct"
df.loc[filtered_df.index, "Via"] = "Direct"

# %%
df['Via'].isna().sum()
# Out:
# 0

# %% [markdown]
# Pretvaranje stupca `Route` natrag u objektni tip podataka i zamjena nan (tekstualnih vrijednosti) vrijednosti s NaN (praznim vrijednostima).

# %%
df['Route'] = df['Route'].astype(object)

# %%
df['Route'] = df['Route'].replace('nan', np.nan)

# %%
df.sample(10)
# Out:
#      Date Published  Rating  Max Rating  \
# 1134     2018-05-15     7.0        10.0
# 2290     2014-01-03     5.0        10.0
# 1652     2016-04-12     9.0        10.0
# 1339     2017-07-20     8.0        10.0
# 412      2022-05-26    10.0        10.0
# 58       2023-10-27     9.0        10.0
# 1664     2016-03-28    10.0        10.0
# 2364     2013-08-12     9.0        10.0
# 514      2021-11-13    10.0        10.0
# 1715     2016-01-14     9.0        10.0
#
#                                                Title              Author  \
# 1134                        "Boeing 787 was cramped"      Dominic Grundy
# 2290                   Qatar Airways customer review       Carlos Blanco
# 1652                          "a first class flight"         Albert Wong
# 1339                 "experience been quite amazing"          P Tarnello
# 412   "hard time finding anything to complain about"   Jan-Erik Karlsson
# 58              "Thank you for the great experience"      Richard Ofiera
# 1664             "very polite, friendly and smiling"           M Mawanga
# 2364                   Qatar Airways customer review              R Nash
# 514                           "We were so impressed"        Joel Barnaby
# 1715                       " I was nicely surprised"  Vittorio Tomasella
#
#              Country                                        Review Body  \
# 1134       Australia    Adelaide to Manchester via Doha. Two flights...
# 2290  United Kingdom  Travelled London (LHR) to Kilimanjaro (JRO) vi...
# 1652           China  ✅ Verified Review |  This flight from Doha to ...
# 1339           Italy  ✅ Verified Review |  Venice to Male via Doha. ...
# 412           Sweden    The first stretch of Bangkok Doha I had a on...
# 58           Germany    Flight QR 176 Oslo - Doha 26.10.2023 We took...
# 1664  United Kingdom  ✅ Verified Review |  London Heathrow to Cape T...
# 2364       Australia  Flew first class CAI-DOH on QR503 on 8th Aug 2...
# 514    United States   We were so impressed with the Q-Suite seats o...
# 1715           Italy  Venice to Seoul via Doha and my first flight w...
#
#      Type Of Traveller       Seat Type                            Route  \
# 1134      Solo Leisure   Economy Class  Adelaide to Manchester via Doha
# 2290           Unknown   Economy Class                              NaN
# 1652          Business  Business Class                       DOH to HKG
# 1339    Family Leisure   Economy Class          Venice to Male via Doha
# 412       Solo Leisure  Business Class    Bangkok to Stockholm via Doha
# 58      Family Leisure   Economy Class                     Oslo to Doha
# 1664      Solo Leisure   Economy Class               LHR to CPT via DOH
# 2364           Unknown     First Class                              NaN
# 514       Solo Leisure  Business Class            Philadelphia to Dubai
# 1715    Couple Leisure   Economy Class               VCE to ICN via DOH
#
#          Date Flown Recommended             Aircraft  Verified          From  \
# 1134       May 2018          no             A350-900       1.0      Adelaide
# 2290   January 2014          no                  NaN       0.0           NaN
# 1652     April 2016         Yes                 A343       1.0           DOH
# 1339  February 2017         Yes  A330-200 / A330-300       1.0        Venice
# 412      April 2022         Yes                  NaN       0.0       Bangkok
# 58     October 2023         Yes         Boeing 787-9       0.0          Oslo
# 1664  February 2016         Yes                  NaN       1.0           LHR
# 2364    August 2013         Yes                  NaN       0.0           NaN
# 514   November 2021         Yes                  NaN       1.0  Philadelphia
# 1715   October 2015         Yes     Boeing 777-300ER       0.0           VCE
#
#               To     Via
# 1134  Manchester    Doha
# 2290         NaN  Direct
# 1652         HKG  Direct
# 1339        Male    Doha
# 412    Stockholm    Doha
# 58          Doha  Direct
# 1664         CPT     DOH
# 2364         NaN  Direct
# 514        Dubai  Direct
# 1715         ICN     DOH

# %%
df.columns
# Out:
# Index(['Date Published', 'Rating', 'Max Rating', 'Title', 'Author', 'Country',
#        'Review Body', 'Type Of Traveller', 'Seat Type', 'Route', 'Date Flown',
#        'Recommended', 'Aircraft', 'Verified', 'From', 'To', 'Via'],
#       dtype='object')

# %%
df = df[['Date Published', 'Rating', 'Max Rating','Author', 'Country','Title', 'Review Body', 'Type Of Traveller', 'Seat Type','Date Flown','Aircraft','Route', 'From','Via', 'To','Verified','Recommended']]

# %%
df.isna().sum()
# Out:
# Date Published          0
# Rating                  0
# Max Rating              0
# Author                  0
# Country                 0
# Title                   0
# Review Body             0
# Type Of Traveller       0
# Seat Type               0
# Date Flown              0
# Aircraft             1087
# Route                 437
# From                  425
# Via                     0
# To                    425
# Verified                0
# Recommended             0
# dtype: int64

# %% [markdown]
# #### Zamijena dupliciranih / netočnih vrijednosti u stupcu "From"

# %%
df['From'].unique()
# Out:
# array(['Tokyo', 'Doha', 'Auckland', 'New Delhi', 'Dusseldorf',
#        'Frankfurt', 'New York', 'Chicago', 'Nice', 'Penang', 'Ahmedabad',
#        'Tbilisi', 'Spain', 'London', 'Beirut', 'Gatwick', 'Bali',
#        'Copenhagen', 'Dallas Ft Worth', 'Manchester', 'Athens',
#        'Ho Chi Minh', 'Düsseldorf', 'Bangkok', 'Ho Chi Minh City',
#        'Kuwait', 'Dubai', 'Milan', 'Brisbane', 'Mahé', 'Lusaka',
#        'Istanbul', 'Melbourne', 'Seattle', 'Brussels', 'Perth',
#        'Denpasar', 'Stockholm', 'Riyadh', 'Zurich', 'Singapore', 'doh',
#        'Oslo', 'Kathmandu', 'Paris', 'Vienna', 'Colombo',
#        'London Heathrow', 'Amsterdam', 'Washington', 'Jakarta',
#        'Abu Dhabi', 'Entebbe', 'Johannesburg', 'Sydney', 'Philadelphia',
#        'Mumbai', 'Warsaw', 'Edinburgh', 'Islamabad', 'Geneva', 'Montreal',
#        'Dallas', 'Hanoi', 'Maputo', 'Rome', 'Jarkata', 'Bucharest',
#        'Phuket', 'Dublin', 'Manila', 'Harare', 'New York JFK', 'Boston',
#        'Los Angeles', 'Madrid', 'Tehran', 'Sofia', 'Lagos', 'Prague',
#        'Delhi', 'Franfurt', 'Nairobi', 'Thailand', 'Atlanta', 'São Paulo',
#        'Ho chi Minh City', 'Algiers', 'Munich', 'Barcelona', 'Sharjah',
#        'Miami', 'Kuala Lumpur', 'San Francisco', 'Zagreb', 'Brisibane',
#        'Cochin', 'Cape Town', 'Kochi', 'madrid', 'Ankara', 'Kigali',
#        'Erbil', 'Maldives', 'Toronto', 'Hyderabad', 'Lagos, Nigeria',
#        'Tunis', 'Madrid ', 'Cairo', 'Male', 'Chennai', 'Bodrum ',
#        'Malaga', 'Chengdu', 'Cebu', 'Belgrade', 'Dammam',
#        'Thiruvananthapuram', 'Adelaide', 'Hong Kong', 'Dallas Fort Worth',
#        'Kozikhode', 'Houston', 'Helsinki', 'Zanzibar', 'Casablanca',
#        'Dhaka', 'Kyiv', 'Berlin', 'Najaf', 'Lahore', 'Seoul', 'Muscat',
#        'Mogadishu', 'Zvartnots', 'Krabi', 'Sulaymaniyah', 'Tblisi',
#        'Lisbon', 'Amman', 'Bangalore', 'Amritsar', 'Yangon', 'Budapest',
#        'Birmingham', 'Dulles', 'Pisa', 'Venice', 'Goa', 'Heathrow',
#        'Cardiff', 'Mahe', 'Kolkata', nan, 'Dar es Salaam', 'Kiev',
#        'Calicut', 'Moscow', 'Paris CDG', 'DEL', 'Doha ', 'Incheon',
#        'Gothenburg', 'Sarajevo', 'Clark', 'London ', 'Canberra',
#        'Mahé, Seychelles', 'Bombay', 'Nagpur', 'Shanghai', 'Karachi',
#        'Marrakech', 'Berlin Tegel', 'BKK', 'Durban', 'Baku', 'MAA',
#        'Salalah', 'Berlin ', 'London Heatrhow', 'MAD', 'Phnom Penh',
#        'Luxor', 'TXL', 'CRK', 'Washington DC', 'BCN', 'DOH', 'KUL', 'DPS',
#        'MNL', 'LHR', 'Medina', 'Taif', 'CPH', 'EZE', 'MAN', 'EDI', 'SVO',
#        'MEL', 'TUN', 'OSL', 'PHL', 'PER', 'PNH', 'AMM', 'VCE', 'ARN',
#        'CPT', 'IAH', 'SYD', 'HKT', 'AMS', 'AUH', 'JNB', 'ATL', 'DXB',
#        'JFK', 'SIN', 'HAN', 'DFW', 'HEL', 'CMB', 'PVG', 'MUC', 'SGN',
#        'IKA', 'BOM', 'LAX', 'BRU', 'ADL', 'KHI', 'LAS', 'ZAG', 'ATH',
#        'ICN', 'BEY', 'SOF', 'SAO', 'FRA', 'TIF', 'ZRH', 'WAW', 'PSA',
#        'MCT', 'BOS', 'CDG', 'CGK', 'IAD', 'HKG', 'BHX', 'ISB', 'GRU',
#        'BLR', 'KIX', 'JED', 'BUD', 'PEN', 'RUH', 'GYD', 'manchester',
#        'MXP', 'HND', 'ORD', 'HBE', 'NBO', 'NRT', 'KTM', 'SAW', 'FCO',
#        'KWI', 'cape town', 'DWC', 'CAI', 'NYC', 'Dar es Salam', 'COK',
#        'Jinnah Int', 'Dubai DWC', 'KUala Lumpur'], dtype=object)

# %%
name_mapping = {
    'doh': 'Doha',
    'Düsseldorf': 'Dusseldorf',
    'Ho chi Minh City': 'Ho Chi Minh',
    'Brisibane': 'Brisbane',
    'madrid': 'Madrid',
    'manchester': 'Manchester',
    'DEL': 'New Delhi',
    'Doha ': 'Doha',
    'Jarkata': 'Jakarta',
    'MAD': 'Madrid',
    'TXL': 'Berlin Tegel',
    'BCN': 'Barcelona',
    'DOH': 'Doha',
    'KUL': 'Kuala Lumpur',
    'DPS': 'Denpasar',
    'MNL': 'Manila',
    'LHR': 'London Heathrow',
    'CPH': 'Copenhagen',
    'EZE': 'Buenos Aires',
    'MAN': 'Manchester',
    'EDI': 'Edinburgh',
    'SVO': 'Moscow',
    'MEL': 'Melbourne',
    'TUN': 'Tunis'
}

# Zamijena vrijednosti u stupcu 'airport_names' koristeći mapiranje
df['From'] = df['From'].replace(name_mapping)

# %%
# Full name mapping rječnik
full_name_mapping = {
    'OSL': 'Oslo',
    'PHL': 'Philadelphia',
    'PER': 'Perth',
    'PNH': 'Phnom Penh',
    'AMM': 'Queen Alia',
    'VCE': 'Venice Marco Polo',
    'ARN': 'Stockholm Arlanda',
    'CPT': 'Cape Town',
    'IAH': 'George Bush',
    'SYD': 'Sydney',
    'HKT': 'Phuket',
    'AMS': 'Amsterdam Schiphol',
    'AUH': 'Abu Dhabi',
    'JNB': 'OR Tambo',
    'ATL': 'Hartsfield-Jackson Atlanta',
    'DXB': 'Dubai',
    'JFK': 'John F. Kennedy',
    'SIN': 'Singapore Changi',
    'HAN': 'Noi Bai',
    'DFW': 'Dallas/Fort Worth',
    'HEL': 'Helsinki-Vantaa',
    'CMB': 'Bandaranaike',
    'PVG': 'Shanghai Pudong',
    'MUC': 'Munich',
    'SGN': 'Tan Son Nhat',
    'IKA': 'Tehran Imam Khomeini',
    'BOM': 'Chhatrapati Shivaji Maharaj',
    'LAX': 'Los Angeles',
    'BRU': 'Brussels',
    'ADL': 'Adelaide',
    'KHI': 'Jinnah',
    'LAS': 'McCarran',
    'ZAG': 'Zagreb',
    'ATH': 'Athens',
    'ICN': 'Incheon',
    'BEY': 'Beirut Rafic Hariri',
    'SOF': 'Sofia',
    'SAO': 'São Paulo Guarulhos',
    'FRA': 'Frankfurt',
    'TIF': 'Taif',
    'ZRH': 'Zurich',
    'WAW': 'Warsaw Chopin',
    'PSA': 'Pisa',
    'MCT': 'Muscat',
    'BOS': 'Logan',
    'CDG': 'Charles de Gaulle',
    'CGK': 'Soekarno Hatta',
    'IAD': 'Washington Dulles',
    'HKG': 'Hong Kong',
    'BHX': 'Birmingham',
    'ISB': 'Islamabad',
    'GRU': 'São Paulo/Guarulhos',
    'BLR': 'Kempegowda',
    'KIX': 'Kansai',
    'JED': 'King Abdulaziz',
    'BUD': 'Budapest Ferenc Liszt',
    'PEN': 'Penang',
    'RUH': 'King Khalid',
    'GYD': 'Heydar Aliyev',
    'MXP': 'Milan Malpensa',
    'HND': 'Haneda',
    'ORD': 'O\'Hare',
    'HBE': 'Borg El Arab',
    'NBO': 'Jomo Kenyatta',
    'NRT': 'Narita',
    'KTM': 'Tribhuvan',
    'SAW': 'Sabiha Gökçen',
    'FCO': 'Leonardo da Vinci Fiumicino',
    'KWI': 'Kuwait',
    'Cape Town': 'Cape Town',
    'DWC': 'Al Maktoum',
    'CAI': 'Cairo',
    'NYC': 'John F. Kennedy',
    'Dar es Salam': 'Julius Nyerere',
    'COK': 'Cochin',
    'Jinnah Int': 'Jinnah',
    'Dubai DWC': 'Al Maktoum',
    'KUala Lumpur': 'Kuala Lumpur'
}

# Zamijena skraćenih imena zračnih luka s punim imenima
df['From'] = df['From'].replace(full_name_mapping)

# %%
# Full name mapping rječnik
full_name_mapping = {
    'Tokyo': 'Tokyo',
    'Doha': 'Doha',
    'Auckland': 'Auckland',
    'New Delhi': 'New Delhi',
    'Dusseldorf': 'Düsseldorf',
    'Frankfurt': 'Frankfurt',
    'New York': 'New York',
    'Chicago': 'Chicago',
    'Nice': 'Nice',
    'Penang': 'Penang',
    'Ahmedabad': 'Ahmedabad',
    'Tbilisi': 'Tbilisi',
    'Spain': 'Spain',
    'London': 'London',
    'Beirut': 'Beirut',
    'Gatwick': 'London Gatwick',
    'Bali': 'Bali',
    'Copenhagen': 'Copenhagen',
    'Dallas Ft Worth': 'Dallas/Fort Worth',
    'Manchester': 'Manchester',
    'Athens': 'Athens',
    'Ho Chi Minh': 'Ho Chi Minh City',
    'Bangkok': 'Bangkok',
    'Ho Chi Minh City': 'Ho Chi Minh City',
    'Kuwait': 'Kuwait',
    'Dubai': 'Dubai',
    'Milan': 'Milan',
    'Brisbane': 'Brisbane',
    'Mahé': 'Mahé',
    'Lusaka': 'Lusaka',
    'Istanbul': 'Istanbul',
    'Melbourne': 'Melbourne',
    'Seattle': 'Seattle',
    'Brussels': 'Brussels',
    'Perth': 'Perth',
    'Denpasar': 'Denpasar',
    'Stockholm': 'Stockholm',
    'Riyadh': 'Riyadh',
    'Zurich': 'Zurich',
    'Singapore': 'Singapore',
    'Oslo': 'Oslo',
    'Kathmandu': 'Kathmandu',
    'Paris': 'Paris',
    'Vienna': 'Vienna',
    'Colombo': 'Colombo',
    'London Heathrow': 'London Heathrow',
    'Amsterdam': 'Amsterdam',
    'Washington': 'Washington',
    'Jakarta': 'Jakarta',
    'Abu Dhabi': 'Abu Dhabi',
    'Entebbe': 'Entebbe',
    'Johannesburg': 'Johannesburg',
    'Sydney': 'Sydney',
    'Philadelphia': 'Philadelphia',
    'Mumbai': 'Mumbai',
    'Warsaw': 'Warsaw',
    'Edinburgh': 'Edinburgh',
    'Islamabad': 'Islamabad',
    'Geneva': 'Geneva',
    'Montreal': 'Montreal',
    'Dallas': 'Dallas',
    'Hanoi': 'Hanoi',
    'Maputo': 'Maputo',
    'Rome': 'Rome',
    'Bucharest': 'Bucharest',
    'Phuket': 'Phuket',
    'Dublin': 'Dublin',
    'Manila': 'Manila',
    'Harare': 'Harare',
    'New York JFK': 'John F. Kennedy',
    'Boston': 'Boston',
    'Los Angeles': 'Los Angeles',
    'Madrid': 'Madrid',
    'Tehran': 'Tehran',
    'Sofia': 'Sofia',
    'Lagos': 'Lagos',
    'Prague': 'Prague',
    'Delhi': 'Delhi',
    'Franfurt': 'Frankfurt',
    'Nairobi': 'Nairobi',
    'Thailand': 'Thailand',
    'Atlanta': 'Atlanta',
    'São Paulo': 'São Paulo',
    'Algiers': 'Algiers',
    'Munich': 'Munich',
    'Barcelona': 'Barcelona',
    'Sharjah': 'Sharjah',
    'Miami': 'Miami',
    'Kuala Lumpur': 'Kuala Lumpur',
    'San Francisco': 'San Francisco',
    'Zagreb': 'Zagreb',
    'Cochin': 'Cochin',
    'Cape Town': 'Cape Town',
    'Kochi': 'Kochi',
    'Ankara': 'Ankara',
    'Kigali': 'Kigali',
    'Erbil': 'Erbil',
    'Maldives': 'Maldives',
    'Toronto': 'Toronto',
    'Hyderabad': 'Hyderabad',
    'Lagos, Nigeria': 'Lagos',
    'Tunis': 'Tunis',
    'Madrid ': 'Madrid',
    'Cairo': 'Cairo',
    'Male': 'Male',
    'Chennai': 'Chennai',
    'Bodrum ': 'Bodrum',
    'Malaga': 'Malaga',
    'Chengdu': 'Chengdu',
    'Cebu': 'Cebu',
    'Belgrade': 'Belgrade',
    'Dammam': 'Dammam',
    'Thiruvananthapuram': 'Thiruvananthapuram',
    'Adelaide': 'Adelaide',
    'Hong Kong': 'Hong Kong',
    'Dallas Fort Worth': 'Dallas/Fort Worth',
    'Kozikhode': 'Kozhikode',
    'Houston': 'Houston',
    'Helsinki': 'Helsinki',
    'Zanzibar': 'Zanzibar',
    'Casablanca': 'Casablanca',
    'Dhaka': 'Dhaka',
    'Kyiv': 'Kyiv',
    'Berlin': 'Berlin',
    'Najaf': 'Najaf',
    'Lahore': 'Lahore',
    'Seoul': 'Seoul',
    'Muscat': 'Muscat',
    'Mogadishu': 'Mogadishu',
    'Zvartnots': 'Zvartnots',
    'Krabi': 'Krabi',
    'Sulaymaniyah': 'Sulaymaniyah',
    'Tblisi': 'Tbilisi',
    'Lisbon': 'Lisbon',
    'Amman': 'Amman',
    'Bangalore': 'Bangalore',
    'Amritsar': 'Amritsar',
    'Yangon': 'Yangon',
    'Budapest': 'Budapest',
    'Birmingham': 'Birmingham',
    'Dulles': 'Dulles',
    'Pisa': 'Pisa',
    'Venice': 'Venice',
    'Goa': 'Goa',
    'Heathrow': 'London Heathrow',
    'Cardiff': 'Cardiff',
    'Mahe': 'Mahé',
    'Kolkata': 'Kolkata',
    'Dar es Salaam': 'Dar es Salaam',
    'Kiev': 'Kiev',
    'Calicut': 'Kozhikode',
    'Moscow': 'Moscow',
    'Paris CDG': 'Charles de Gaulle',
    'Incheon': 'Incheon',
    'Gothenburg': 'Gothenburg',
    'Sarajevo': 'Sarajevo',
    'Clark': 'Clark',
    'London ': 'London',
    'Canberra': 'Canberra',
    'Mahé, Seychelles': 'Mahé',
    'Bombay': 'Mumbai',
    'Nagpur': 'Nagpur',
    'Shanghai': 'Shanghai',
    'Karachi': 'Karachi',
    'Marrakech': 'Marrakech',
    'Berlin Tegel': 'Berlin',
    'BKK': 'Bangkok',
    'Durban': 'Durban',
    'Baku': 'Baku',
    'MAA': 'Chennai',
    'Salalah': 'Salalah',
    'Berlin ': 'Berlin',
    'London Heatrhow': 'London Heathrow',
    'Phnom Penh': 'Phnom Penh',
    'Luxor': 'Luxor',
    'CRK': 'Clark',
    'Washington DC': 'Washington',
    'Medina': 'Medina',
    'Taif': 'Taif',
    'Buenos Aires': 'Buenos Aires',
    'Queen Alia': 'Queen Alia International',
    'Venice Marco Polo': 'Venice Marco Polo',
    'Stockholm Arlanda': 'Stockholm Arlanda',
    'George Bush': 'George Bush Intercontinental',
    'Amsterdam Schiphol': 'Amsterdam Airport Schiphol',
    'OR Tambo': 'O. R. Tambo International',
    'Hartsfield-Jackson Atlanta': 'Hartsfield-Jackson Atlanta International',
    'John F. Kennedy': 'John F. Kennedy International',
    'Singapore Changi': 'Singapore Changi Airport',
    'Noi Bai': 'Noi Bai International',
    'Dallas/Fort Worth': 'Dallas/Fort Worth International',
    'Helsinki-Vantaa': 'Helsinki Airport',
    'Bandaranaike': 'Bandaranaike International',
    'Shanghai Pudong': 'Shanghai Pudong International',
    'Tan Son Nhat': 'Tan Son Nhat International',
    'Tehran Imam Khomeini': 'Imam Khomeini International',
    'Chhatrapati Shivaji Maharaj': 'Chhatrapati Shivaji Maharaj International',
    'Jinnah': 'Jinnah International',
    'McCarran': 'McCarran International',
    'Beirut Rafic Hariri': 'Beirut Rafic Hariri International',
    'São Paulo Guarulhos': 'São Paulo/Guarulhos International',
    'Warsaw Chopin': 'Warsaw Chopin Airport',
    'Logan': 'Logan International',
    'Charles de Gaulle': 'Charles de Gaulle Airport',
    'Soekarno Hatta': 'Soekarno-Hatta International',
    'Washington Dulles': 'Washington Dulles International',
    'São Paulo/Guarulhos': 'São Paulo/Guarulhos International',
    'Kempegowda': 'Kempegowda International',
    'Kansai': 'Kansai International',
    'King Abdulaziz': 'King Abdulaziz International',
    'Budapest Ferenc Liszt': 'Budapest Ferenc Liszt International',
    'King Khalid': 'King Khalid International',
    'Heydar Aliyev': 'Heydar Aliyev International',
    'Milan Malpensa': 'Milan Malpensa Airport',
    'Haneda': 'Haneda Airport',
    "O'Hare": "O'Hare International",
    'Borg El Arab': 'Borg El Arab International',
    'Jomo Kenyatta': 'Jomo Kenyatta International',
    'Narita': 'Narita International',
    'Tribhuvan': 'Tribhuvan International',
    'Sabiha Gökçen': 'Sabiha Gökçen International',
    'Leonardo da Vinci Fiumicino': 'Leonardo da Vinci-Fiumicino Airport',
    'cape town': 'Cape Town',
    'Al Maktoum': 'Al Maktoum International',
    'Julius Nyerere': 'Julius Nyerere International'
}

# Zamijena imena zračnih luka s punim imenima
df['From'] = df['From'].replace(full_name_mapping)

# %%
df['From'].unique()
# Out:
# array(['Tokyo', 'Doha', 'Auckland', 'New Delhi', 'Düsseldorf',
#        'Frankfurt', 'New York', 'Chicago', 'Nice', 'Penang', 'Ahmedabad',
#        'Tbilisi', 'Spain', 'London', 'Beirut', 'London Gatwick', 'Bali',
#        'Copenhagen', 'Dallas/Fort Worth', 'Manchester', 'Athens',
#        'Ho Chi Minh City', 'Bangkok', 'Kuwait', 'Dubai', 'Milan',
#        'Brisbane', 'Mahé', 'Lusaka', 'Istanbul', 'Melbourne', 'Seattle',
#        'Brussels', 'Perth', 'Denpasar', 'Stockholm', 'Riyadh', 'Zurich',
#        'Singapore', 'Oslo', 'Kathmandu', 'Paris', 'Vienna', 'Colombo',
#        'London Heathrow', 'Amsterdam', 'Washington', 'Jakarta',
#        'Abu Dhabi', 'Entebbe', 'Johannesburg', 'Sydney', 'Philadelphia',
#        'Mumbai', 'Warsaw', 'Edinburgh', 'Islamabad', 'Geneva', 'Montreal',
#        'Dallas', 'Hanoi', 'Maputo', 'Rome', 'Bucharest', 'Phuket',
#        'Dublin', 'Manila', 'Harare', 'John F. Kennedy', 'Boston',
#        'Los Angeles', 'Madrid', 'Tehran', 'Sofia', 'Lagos', 'Prague',
#        'Delhi', 'Nairobi', 'Thailand', 'Atlanta', 'São Paulo', 'Algiers',
#        'Munich', 'Barcelona', 'Sharjah', 'Miami', 'Kuala Lumpur',
#        'San Francisco', 'Zagreb', 'Cochin', 'Cape Town', 'Kochi',
#        'Ankara', 'Kigali', 'Erbil', 'Maldives', 'Toronto', 'Hyderabad',
#        'Tunis', 'Cairo', 'Male', 'Chennai', 'Bodrum', 'Malaga', 'Chengdu',
#        'Cebu', 'Belgrade', 'Dammam', 'Thiruvananthapuram', 'Adelaide',
#        'Hong Kong', 'Kozhikode', 'Houston', 'Helsinki', 'Zanzibar',
#        'Casablanca', 'Dhaka', 'Kyiv', 'Berlin', 'Najaf', 'Lahore',
#        'Seoul', 'Muscat', 'Mogadishu', 'Zvartnots', 'Krabi',
#        'Sulaymaniyah', 'Lisbon', 'Amman', 'Bangalore', 'Amritsar',
#        'Yangon', 'Budapest', 'Birmingham', 'Dulles', 'Pisa', 'Venice',
#        'Goa', 'Cardiff', 'Kolkata', nan, 'Dar es Salaam', 'Kiev',
#        'Moscow', 'Charles de Gaulle', 'Incheon', 'Gothenburg', 'Sarajevo',
#        'Clark', 'Canberra', 'Nagpur', 'Shanghai', 'Karachi', 'Marrakech',
#        'Durban', 'Baku', 'Salalah', 'Phnom Penh', 'Luxor', 'Medina',
#        'Taif', 'Buenos Aires', 'Queen Alia International',
#        'Venice Marco Polo', 'Stockholm Arlanda',
#        'George Bush Intercontinental', 'Amsterdam Airport Schiphol',
#        'O. R. Tambo International',
#        'Hartsfield-Jackson Atlanta International',
#        'John F. Kennedy International', 'Singapore Changi Airport',
#        'Noi Bai International', 'Dallas/Fort Worth International',
#        'Helsinki Airport', 'Bandaranaike International',
#        'Shanghai Pudong International', 'Tan Son Nhat International',
#        'Imam Khomeini International',
#        'Chhatrapati Shivaji Maharaj International',
#        'Jinnah International', 'McCarran International',
#        'Beirut Rafic Hariri International',
#        'São Paulo/Guarulhos International', 'Warsaw Chopin Airport',
#        'Logan International', 'Charles de Gaulle Airport',
#        'Soekarno-Hatta International', 'Washington Dulles International',
#        'Kempegowda International', 'Kansai International',
#        'King Abdulaziz International',
#        'Budapest Ferenc Liszt International', 'King Khalid International',
#        'Heydar Aliyev International', 'Milan Malpensa Airport',
#        'Haneda Airport', "O'Hare International",
#        'Borg El Arab International', 'Jomo Kenyatta International',
#        'Narita International', 'Tribhuvan International',
#        'Sabiha Gökçen International',
#        'Leonardo da Vinci-Fiumicino Airport', 'Al Maktoum International',
#        'Julius Nyerere International'], dtype=object)

# %% [markdown]
# #### Zamijena dupliciranih / netočnih vrijednosti u stupcu "To"

# %%
df['To'].unique()
# Out:
# array(['London Heathrow', 'Montreal', 'Perth', 'Doha', 'London',
#        'San Francisco', 'Kilimanjaro', 'Melbourne', 'Johannesburg',
#        'Dubai', 'Adelaide', 'Detroit', 'Singapore', 'Auckland', 'Erbil',
#        'Goa', 'Brussels', 'Kolkata', 'Bangkok', 'Frankfurt', 'Sydney',
#        'Manchester', 'Warsaw', 'Tokyo', 'Delhi', 'Kuala Lumpur',
#        'Salalah', 'Amsterdam', 'Tbilisi', 'Lyon', 'Denpasar',
#        'Washington', 'Luanda', 'Lusaka', 'Milan', 'kwi', 'Sao Paulo',
#        'Chicago', 'Seattle', 'Kuwait', 'Gatwick', 'Denpasar Bali',
#        'Cape Town', 'Brisbane', 'Kathmanda', 'Muscat', 'Athens', 'Vienna',
#        'Rome', 'Bahrain', 'Colombo', 'Abu Dhabi', 'Istanbul', 'Barcelona',
#        'Paris', 'Phuket', 'Edinburgh', 'Kochi', 'Tehran', 'Mumbai',
#        'Zurich', 'Berlin', 'New York JFK', 'Windhoek', 'Philadelphia',
#        'Riyadh', 'Jakarta', 'Lagos', 'Cochin', 'Baghdad', 'Bali', 'Dhaka',
#        'Bucharest', 'Hanoi', 'Dallas', 'Manila', 'Ord', 'Dublin',
#        'Zagreb', 'Madrid', 'São Paulo', 'Nairobi', 'Hamad', 'Diha',
#        'Bangalore', 'sharjah', 'Male', 'Islamabad', 'Ho Chi Minh',
#        'Prague', 'Toronto', 'Karachi', 'Munich', 'Ho Chi Minh City',
#        'Oslo', 'Boston', 'Dammam', 'Lahore', 'Miami', 'Hyderabad',
#        ' Doha', 'Mactan', 'Cairo', 'Cebu', 'Budapest', 'Atlanta',
#        'Helsinki', 'London Gatwick', 'Beirut', 'Entebbe', 'New York',
#        'San Diego', 'Hong Kong', 'Nagpur', 'Los Angeles', 'Durban',
#        'Chennai', 'Amman', 'Washington DC', 'Kozhikode', 'Ahmedabad',
#        'Stockholm', 'Kathmandu', 'Copenhagen', "Chicago O'Hare",
#        'Houston', 'Sialkot', 'Medina', 'Baku', 'Moscow', 'Cape town',
#        'Casablanca', 'Lahore VIA \\DOHA', 'Larnaca', 'Clark', 'Jeddah',
#        'Maldives', 'Keflavik', 'Basra', 'Yerevan', 'Bengaluru',
#        'Sao Paulo GRU', 'Tokyo Narita', 'Zanzibar', 'Bermuda',
#        'Washington Dulles', 'Seoul Incheon', 'Tallinn', 'Dallas Ft Worth',
#        'Vancouver', 'Cochi', 'Danang', 'Najaf', 'St Petersburg',
#        'Da Nang', 'Kyiv', 'Shanghai', 'Antalya', 'Sofia', 'Bombay',
#        'Kigali', 'Phnom Penh', 'Gothenburg', 'Langkawi', 'Penang',
#        'Birmingham', 'Multan', nan, 'Seoul', 'Venice', 'Nice', 'Tunis',
#        'Ankara', 'Calicut', 'BCN', 'Amritsar', 'Rio de Janeiro',
#        ' Gatwick', 'Dar Es Salaam', 'Geneva', 'Trivandrum', 'Cardiff',
#        'Hi Chi Minh City', 'Dublin ', 'Paris CDG', 'Chiang Mai',
#        'Incheon', 'DOH', 'Guangzhou', 'Chennai return', 'JFK', 'Kiev',
#        'Hyderabad ', 'Belgrade', 'Melbourne Australia', 'Yangon', 'SIN',
#        'FRA', 'Tblisi', 'Chongqing', 'Khartoum', 'Thiruvananthapuram',
#        'DPS', 'Pnom Penh', 'MAD', 'BKK', 'CPH', 'Alexandria', 'LHR',
#        'DXB', 'Taif', 'EDI', 'CMB', 'BOM', 'KUL', 'CMN', 'ADL', 'NRT',
#        'SGN', 'MUC', 'KTM', 'AUH', 'GOI', 'HKT', 'COK', 'CCU',
#        'BRUvia DOH', 'PER', 'ISB', 'KWI', 'DWC', 'MCT', 'AMM', 'DEL',
#        'MEL', 'JRO', 'CAI', 'CDG', 'FCO', 'PNH', 'MAN', 'ATL', 'VCE',
#        'JNB', 'CGK', 'PHL', 'KHI', 'ATH', 'HKG', 'TXL', 'DAR', 'MNL',
#        'LHE', 'MLE', 'GVA', 'ZRH', 'WAW', 'ORD', 'CPT', 'LAX', 'HAN',
#        'PVG', 'AKL', 'SYD', 'HYD', 'ICN', 'IST', 'BRU', 'IAD', 'DUR',
#        'BHX', 'BEG', 'CNB', 'VIE', 'OSL', 'MCO', 'DFW', 'goa', 'DAC',
#        'AMS', 'YUL', 'SNG', 'HND', 'AMD', 'LOS', 'NBO', 'SYZ', 'ARN',
#        'GYD', 'STO', 'brussels', 'RGN', 'Doha airport', 'Istanbul (SAW)',
#        'Johanesburg', 'Suvarnabhumi', 'MIA', 'Heathrow', 'EZE',
#        'Bandaranaike'], dtype=object)

# %%
name_mapping = {
    'doh': 'Doha',
    'Düsseldorf': 'Dusseldorf',
    'Ho chi Minh City': 'Ho Chi Minh',
    'Brisibane': 'Brisbane',
    'madrid': 'Madrid',
    'manchester': 'Manchester',
    'DEL': 'New Delhi',
    'Doha ': 'Doha',
    'Jarkata': 'Jakarta',
    'MAD': 'Madrid',
    'TXL': 'Berlin Tegel',
    'BCN': 'Barcelona',
    'DOH': 'Doha',
    'KUL': 'Kuala Lumpur',
    'DPS': 'Denpasar',
    'MNL': 'Manila',
    'LHR': 'London Heathrow',
    'CPH': 'Copenhagen',
    'EZE': 'Buenos Aires',
    'MAN': 'Manchester',
    'EDI': 'Edinburgh',
    'SVO': 'Moscow',
    'MEL': 'Melbourne',
    'TUN': 'Tunis'
}

# Zamijena vrijednosti u stupcu 'airport_names' koristeći mapiranje
df['To'] = df['To'].replace(name_mapping)

# %%
# Full name mapping rječnik
full_name_mapping = {
    'OSL': 'Oslo',
    'PHL': 'Philadelphia',
    'PER': 'Perth',
    'PNH': 'Phnom Penh',
    'AMM': 'Queen Alia',
    'VCE': 'Venice Marco Polo',
    'ARN': 'Stockholm Arlanda',
    'CPT': 'Cape Town',
    'IAH': 'George Bush',
    'SYD': 'Sydney',
    'HKT': 'Phuket',
    'AMS': 'Amsterdam Schiphol',
    'AUH': 'Abu Dhabi',
    'JNB': 'OR Tambo',
    'ATL': 'Hartsfield-Jackson Atlanta',
    'DXB': 'Dubai',
    'JFK': 'John F. Kennedy',
    'SIN': 'Singapore Changi',
    'HAN': 'Noi Bai',
    'DFW': 'Dallas/Fort Worth',
    'HEL': 'Helsinki-Vantaa',
    'CMB': 'Bandaranaike',
    'PVG': 'Shanghai Pudong',
    'MUC': 'Munich',
    'SGN': 'Tan Son Nhat',
    'IKA': 'Tehran Imam Khomeini',
    'BOM': 'Chhatrapati Shivaji Maharaj',
    'LAX': 'Los Angeles',
    'BRU': 'Brussels',
    'ADL': 'Adelaide',
    'KHI': 'Jinnah',
    'LAS': 'McCarran',
    'ZAG': 'Zagreb',
    'ATH': 'Athens',
    'ICN': 'Incheon',
    'BEY': 'Beirut Rafic Hariri',
    'SOF': 'Sofia',
    'SAO': 'São Paulo Guarulhos',
    'FRA': 'Frankfurt',
    'TIF': 'Taif',
    'ZRH': 'Zurich',
    'WAW': 'Warsaw Chopin',
    'PSA': 'Pisa',
    'MCT': 'Muscat',
    'BOS': 'Logan',
    'CDG': 'Charles de Gaulle',
    'CGK': 'Soekarno Hatta',
    'IAD': 'Washington Dulles',
    'HKG': 'Hong Kong',
    'BHX': 'Birmingham',
    'ISB': 'Islamabad',
    'GRU': 'São Paulo/Guarulhos',
    'BLR': 'Kempegowda',
    'KIX': 'Kansai',
    'JED': 'King Abdulaziz',
    'BUD': 'Budapest Ferenc Liszt',
    'PEN': 'Penang',
    'RUH': 'King Khalid',
    'GYD': 'Heydar Aliyev',
    'MXP': 'Milan Malpensa',
    'HND': 'Haneda',
    'ORD': 'O\'Hare',
    'HBE': 'Borg El Arab',
    'NBO': 'Jomo Kenyatta',
    'NRT': 'Narita',
    'KTM': 'Tribhuvan',
    'SAW': 'Sabiha Gökçen',
    'FCO': 'Leonardo da Vinci Fiumicino',
    'KWI': 'Kuwait',
    'Cape Town': 'Cape Town',
    'DWC': 'Al Maktoum',
    'CAI': 'Cairo',
    'NYC': 'John F. Kennedy',
    'Dar es Salam': 'Julius Nyerere',
    'COK': 'Cochin',
    'Jinnah Int': 'Jinnah',
    'Dubai DWC': 'Al Maktoum',
    'KUala Lumpur': 'Kuala Lumpur'
}

# Zamijena skraćenih imena zračnih luka s punim imenima
df['To'] = df['To'].replace(full_name_mapping)

# %%
# Full name mapping rječnik s ispravkama
full_name_mapping = {
    'Tokyo': 'Tokyo',
    'Doha': 'Doha',
    'Auckland': 'Auckland',
    'New Delhi': 'New Delhi',
    'Dusseldorf': 'Düsseldorf',
    'Frankfurt': 'Frankfurt',
    'New York': 'New York',
    'Chicago': 'Chicago',
    'Nice': 'Nice',
    'Penang': 'Penang',
    'Ahmedabad': 'Ahmedabad',
    'Tbilisi': 'Tbilisi',
    'Spain': 'Spain',
    'London': 'London',
    'Beirut': 'Beirut',
    'Gatwick': 'London Gatwick',
    'Bali': 'Bali',
    'Copenhagen': 'Copenhagen',
    'Dallas Ft Worth': 'Dallas/Fort Worth',
    'Manchester': 'Manchester',
    'Athens': 'Athens',
    'Ho Chi Minh': 'Ho Chi Minh City',
    'Bangkok': 'Bangkok',
    'Ho Chi Minh City': 'Ho Chi Minh City',
    'Kuwait': 'Kuwait',
    'Dubai': 'Dubai',
    'Milan': 'Milan',
    'Brisbane': 'Brisbane',
    'Mahé': 'Mahé',
    'Lusaka': 'Lusaka',
    'Istanbul': 'Istanbul',
    'Melbourne': 'Melbourne',
    'Seattle': 'Seattle',
    'Brussels': 'Brussels',
    'Perth': 'Perth',
    'Denpasar': 'Denpasar',
    'Stockholm': 'Stockholm',
    'Riyadh': 'Riyadh',
    'Zurich': 'Zurich',
    'Singapore': 'Singapore',
    'Oslo': 'Oslo',
    'Kathmandu': 'Kathmandu',
    'Paris': 'Paris',
    'Vienna': 'Vienna',
    'Colombo': 'Colombo',
    'London Heathrow': 'London Heathrow',
    'Amsterdam': 'Amsterdam',
    'Washington': 'Washington',
    'Jakarta': 'Jakarta',
    'Abu Dhabi': 'Abu Dhabi',
    'Entebbe': 'Entebbe',
    'Johannesburg': 'Johannesburg',
    'Sydney': 'Sydney',
    'Philadelphia': 'Philadelphia',
    'Mumbai': 'Mumbai',
    'Warsaw': 'Warsaw',
    'Edinburgh': 'Edinburgh',
    'Islamabad': 'Islamabad',
    'Geneva': 'Geneva',
    'Montreal': 'Montreal',
    'Dallas': 'Dallas',
    'Hanoi': 'Hanoi',
    'Maputo': 'Maputo',
    'Rome': 'Rome',
    'Bucharest': 'Bucharest',
    'Phuket': 'Phuket',
    'Dublin': 'Dublin',
    'Manila': 'Manila',
    'Harare': 'Harare',
    'New York JFK': 'John F. Kennedy',
    'Boston': 'Boston',
    'Los Angeles': 'Los Angeles',
    'Madrid': 'Madrid',
    'Tehran': 'Tehran',
    'Sofia': 'Sofia',
    'Lagos': 'Lagos',
    'Prague': 'Prague',
    'Delhi': 'Delhi',
    'Franfurt': 'Frankfurt',
    'Nairobi': 'Nairobi',
    'Thailand': 'Thailand',
    'Atlanta': 'Atlanta',
    'São Paulo': 'São Paulo',
    'Algiers': 'Algiers',
    'Munich': 'Munich',
    'Barcelona': 'Barcelona',
    'Sharjah': 'Sharjah',
    'Miami': 'Miami',
    'Kuala Lumpur': 'Kuala Lumpur',
    'San Francisco': 'San Francisco',
    'Zagreb': 'Zagreb',
    'Cochin': 'Cochin',
    'Cape Town': 'Cape Town',
    'Kochi': 'Kochi',
    'Ankara': 'Ankara',
    'Kigali': 'Kigali',
    'Erbil': 'Erbil',
    'Maldives': 'Maldives',
    'Toronto': 'Toronto',
    'Hyderabad': 'Hyderabad',
    'Lagos, Nigeria': 'Lagos',
    'Tunis': 'Tunis',
    'Madrid ': 'Madrid',
    'Cairo': 'Cairo',
    'Male': 'Male',
    'Chennai': 'Chennai',
    'Bodrum ': 'Bodrum',
    'Malaga': 'Malaga',
    'Chengdu': 'Chengdu',
    'Cebu': 'Cebu',
    'Belgrade': 'Belgrade',
    'Dammam': 'Dammam',
    'Thiruvananthapuram': 'Thiruvananthapuram',
    'Adelaide': 'Adelaide',
    'Hong Kong': 'Hong Kong',
    'Dallas Fort Worth': 'Dallas/Fort Worth',
    'Kozikhode': 'Kozhikode',
    'Houston': 'Houston',
    'Helsinki': 'Helsinki',
    'Zanzibar': 'Zanzibar',
    'Casablanca': 'Casablanca',
    'Dhaka': 'Dhaka',
    'Kyiv': 'Kyiv',
    'Berlin': 'Berlin',
    'Najaf': 'Najaf',
    'Lahore': 'Lahore',
    'Seoul': 'Seoul',
    'Muscat': 'Muscat',
    'Mogadishu': 'Mogadishu',
    'Zvartnots': 'Zvartnots',
    'Krabi': 'Krabi',
    'Sulaymaniyah': 'Sulaymaniyah',
    'Tblisi': 'Tbilisi',
    'Lisbon': 'Lisbon',
    'Amman': 'Amman',
    'Bangalore': 'Bangalore',
    'Amritsar': 'Amritsar',
    'Yangon': 'Yangon',
    'Budapest': 'Budapest',
    'Birmingham': 'Birmingham',
    'Dulles': 'Dulles',
    'Pisa': 'Pisa',
    'Venice': 'Venice',
    'Goa': 'Goa',
    'Heathrow': 'London Heathrow',
    'Cardiff': 'Cardiff',
    'Mahe': 'Mahé',
    'Kolkata': 'Kolkata',
    'Dar es Salaam': 'Dar es Salaam',
    'Kiev': 'Kiev',
    'Calicut': 'Kozhikode',
    'Moscow': 'Moscow',
    'Paris CDG': 'Charles de Gaulle',
    'Incheon': 'Incheon',
    'Gothenburg': 'Gothenburg',
    'Sarajevo': 'Sarajevo',
    'Clark': 'Clark',
    'London ': 'London',
    'Canberra': 'Canberra',
    'Mahé, Seychelles': 'Mahé',
    'Bombay': 'Mumbai',
    'Nagpur': 'Nagpur',
    'Shanghai': 'Shanghai',
    'Karachi': 'Karachi',
    'Marrakech': 'Marrakech',
    'Berlin Tegel': 'Berlin',
    'BKK': 'Bangkok',
    'Durban': 'Durban',
    'Baku': 'Baku',
    'MAA': 'Chennai',
    'Salalah': 'Salalah',
    'Berlin ': 'Berlin',
    'London Heatrhow': 'London Heathrow',
    'Phnom Penh': 'Phnom Penh',
    'Luxor': 'Luxor',
    'CRK': 'Clark',
    'Washington DC': 'Washington',
    'Medina': 'Medina',
    'Taif': 'Taif',
    'Buenos Aires': 'Buenos Aires',
    'Queen Alia': 'Queen Alia International',
    'Venice Marco Polo': 'Venice Marco Polo',
    'Stockholm Arlanda': 'Stockholm Arlanda',
    'George Bush': 'George Bush Intercontinental',
    'Amsterdam Schiphol': 'Amsterdam Airport Schiphol',
    'OR Tambo': 'O. R. Tambo International',
    'Hartsfield-Jackson Atlanta': 'Hartsfield-Jackson Atlanta International',
    'John F. Kennedy': 'John F. Kennedy International',
    'Singapore Changi': 'Singapore Changi Airport',
    'Noi Bai': 'Noi Bai International',
    'Dallas/Fort Worth': 'Dallas/Fort Worth International',
    'Helsinki-Vantaa': 'Helsinki Airport',
    'Bandaranaike': 'Bandaranaike International',
    'Shanghai Pudong': 'Shanghai Pudong International',
    'Tan Son Nhat': 'Tan Son Nhat International',
    'Tehran Imam Khomeini': 'Imam Khomeini International',
    'Chhatrapati Shivaji Maharaj': 'Chhatrapati Shivaji Maharaj International',
    'Jinnah': 'Jinnah International',
    'McCarran': 'McCarran International',
    'Beirut Rafic Hariri': 'Beirut Rafic Hariri International',
    'São Paulo Guarulhos': 'São Paulo/Guarulhos International',
    'Warsaw Chopin': 'Warsaw Chopin Airport',
    'Logan': 'Logan International',
    'Charles de Gaulle': 'Charles de Gaulle Airport',
    'Soekarno Hatta': 'Soekarno-Hatta International',
    'Washington Dulles': 'Washington Dulles International',
    'São Paulo/Guarulhos': 'São Paulo/Guarulhos International',
    'Kempegowda': 'Kempegowda International',
    'Kansai': 'Kansai International',
    'King Abdulaziz': 'King Abdulaziz International',
    'Budapest Ferenc Liszt': 'Budapest Ferenc Liszt International',
    'King Khalid': 'King Khalid International',
    'Heydar Aliyev': 'Heydar Aliyev International',
    'Milan Malpensa': 'Milan Malpensa Airport',
    'Haneda': 'Haneda Airport',
    "O'Hare": "O'Hare International",
    'Borg El Arab': 'Borg El Arab International',
    'Jomo Kenyatta': 'Jomo Kenyatta International',
    'Narita': 'Narita International',
    'Tribhuvan': 'Tribhuvan International',
    'Sabiha Gökçen': 'Sabiha Gökçen International',
    'Leonardo da Vinci Fiumicino': 'Leonardo da Vinci-Fiumicino Airport',
    'cape town': 'Cape Town',
    'Al Maktoum': 'Al Maktoum International',
    'Julius Nyerere': 'Julius Nyerere International'
}

# Zamijena naziva zračnih luka s točnim punim imenima
df['To'] = df['To'].replace(full_name_mapping)

# %%
city_mapping = {
    'London Heathrow': 'London',
    'Montreal': 'Montreal',
    'Perth': 'Perth',
    'Doha': 'Doha',
    'London': 'London',
    'San Francisco': 'San Francisco',
    'Kilimanjaro': 'Kilimanjaro',
    'Melbourne': 'Melbourne',
    'Johannesburg': 'Johannesburg',
    'Dubai': 'Dubai',
    'Adelaide': 'Adelaide',
    'Detroit': 'Detroit',
    'Singapore': 'Singapore',
    'Auckland': 'Auckland',
    'Erbil': 'Erbil',
    'Goa': 'Goa',
    'Brussels': 'Brussels',
    'Kolkata': 'Kolkata',
    'Bangkok': 'Bangkok',
    'Frankfurt': 'Frankfurt',
    'Sydney': 'Sydney',
    'Manchester': 'Manchester',
    'Warsaw': 'Warsaw',
    'Tokyo': 'Tokyo',
    'Delhi': 'New Delhi',
    'Kuala Lumpur': 'Kuala Lumpur',
    'Salalah': 'Salalah',
    'Amsterdam': 'Amsterdam',
    'Tbilisi': 'Tbilisi',
    'Lyon': 'Lyon',
    'Denpasar': 'Denpasar',
    'Washington': 'Washington',
    'Luanda': 'Luanda',
    'Lusaka': 'Lusaka',
    'Milan': 'Milan',
    'kwi': 'Kuwait City',
    'Sao Paulo': 'Sao Paulo',
    'Chicago': 'Chicago',
    'Seattle': 'Seattle',
    'Kuwait': 'Kuwait City',
    'London Gatwick': 'London',
    'Denpasar Bali': 'Denpasar',
    'Cape Town': 'Cape Town',
    'Brisbane': 'Brisbane',
    'Kathmanda': 'Kathmandu',
    'Muscat': 'Muscat',
    'Athens': 'Athens',
    'Vienna': 'Vienna',
    'Rome': 'Rome',
    'Bahrain': 'Manama',
    'Colombo': 'Colombo',
    'Abu Dhabi': 'Abu Dhabi',
    'Istanbul': 'Istanbul',
    'Barcelona': 'Barcelona',
    'Paris': 'Paris',
    'Phuket': 'Phuket',
    'Edinburgh': 'Edinburgh',
    'Kochi': 'Kochi',
    'Tehran': 'Tehran',
    'Mumbai': 'Mumbai',
    'Zurich': 'Zurich',
    'Berlin': 'Berlin',
    'John F. Kennedy': 'New York',
    'Windhoek': 'Windhoek',
    'Philadelphia': 'Philadelphia',
    'Riyadh': 'Riyadh',
    'Jakarta': 'Jakarta',
    'Lagos': 'Lagos',
    'Cochin': 'Kochi',
    'Baghdad': 'Baghdad',
    'Dhaka': 'Dhaka',
    'Bucharest': 'Bucharest',
    'Hanoi': 'Hanoi',
    'Dallas': 'Dallas',
    'Manila': 'Manila',
    'Ord': 'Chicago',
    'Dublin': 'Dublin',
    'Zagreb': 'Zagreb',
    'Madrid': 'Madrid',
    'São Paulo': 'Sao Paulo',
    'Nairobi': 'Nairobi',
    'Hamad': 'Doha',
    'Diha': 'Doha',
    'Bangalore': 'Bengaluru',
    'sharjah': 'Sharjah',
    'Male': 'Male',
    'Islamabad': 'Islamabad',
    'Ho Chi Minh City': 'Ho Chi Minh City',
    'Prague': 'Prague',
    'Toronto': 'Toronto',
    'Karachi': 'Karachi',
    'Munich': 'Munich',
    'Oslo': 'Oslo',
    'Boston': 'Boston',
    'Dammam': 'Dammam',
    'Lahore': 'Lahore',
    'Miami': 'Miami',
    'Hyderabad': 'Hyderabad',
    ' Doha': 'Doha',
    'Mactan': 'Lapu-Lapu City',
    'Cairo': 'Cairo',
    'Cebu': 'Cebu City',
    'Budapest': 'Budapest',
    'Atlanta': 'Atlanta',
    'Helsinki': 'Helsinki',
    'Beirut': 'Beirut',
    'Entebbe': 'Entebbe',
    'New York': 'New York',
    'San Diego': 'San Diego',
    'Hong Kong': 'Hong Kong',
    'Nagpur': 'Nagpur',
    'Los Angeles': 'Los Angeles',
    'Durban': 'Durban',
    'Chennai': 'Chennai',
    'Amman': 'Amman',
    'Kozhikode': 'Kozhikode',
    'Ahmedabad': 'Ahmedabad',
    'Stockholm': 'Stockholm',
    'Kathmandu': 'Kathmandu',
    'Copenhagen': 'Copenhagen',
    "Chicago O'Hare": 'Chicago',
    'Houston': 'Houston',
    'Sialkot': 'Sialkot',
    'Medina': 'Medina',
    'Baku': 'Baku',
    'Moscow': 'Moscow',
    'Cape town': 'Cape Town',
    'Casablanca': 'Casablanca',
    'Lahore VIA \\DOHA': 'Lahore',
    'Larnaca': 'Larnaca',
    'Clark': 'Clark Freeport Zone',
    'Jeddah': 'Jeddah',
    'Maldives': 'Malé',
    'Keflavik': 'Keflavík',
    'Basra': 'Basra',
    'Yerevan': 'Yerevan',
    'Bengaluru': 'Bengaluru',
    'Sao Paulo GRU': 'Sao Paulo',
    'Tokyo Narita': 'Tokyo',
    'Zanzibar': 'Zanzibar City',
    'Bermuda': 'Hamilton',
    'Washington Dulles International': 'Washington',
    'Seoul Incheon': 'Seoul',
    'Tallinn': 'Tallinn',
    'Dallas/Fort Worth': 'Dallas',
    'Vancouver': 'Vancouver',
    'Cochi': 'Kochi',
    'Danang': 'Da Nang',
    'Najaf': 'Najaf',
    'St Petersburg': 'St. Petersburg',
    'Da Nang': 'Da Nang',
    'Kyiv': 'Kyiv',
    'Shanghai': 'Shanghai',
    'Antalya': 'Antalya',
    'Sofia': 'Sofia',
    'Kigali': 'Kigali',
    'Phnom Penh': 'Phnom Penh',
    'Gothenburg': 'Gothenburg',
    'Langkawi': 'Langkawi',
    'Penang': 'George Town',
    'Birmingham': 'Birmingham',
    'Multan': 'Multan',
    'nan': 'Unknown',
    'Seoul': 'Seoul',
    'Venice': 'Venice',
    'Nice': 'Nice',
    'Tunis': 'Tunis',
    'Ankara': 'Ankara',
    'Amritsar': 'Amritsar',
    'Rio de Janeiro': 'Rio de Janeiro',
    ' Gatwick': 'London',
    'Dar Es Salaam': 'Dar es Salaam',
    'Geneva': 'Geneva',
    'Trivandrum': 'Thiruvananthapuram',
    'Cardiff': 'Cardiff',
    'Hi Chi Minh City': 'Ho Chi Minh City',
    'Dublin ': 'Dublin',
    'Charles de Gaulle': 'Paris',
    'Chiang Mai': 'Chiang Mai',
    'Incheon': 'Incheon',
    'Guangzhou': 'Guangzhou',
    'Chennai return': 'Chennai',
    'John F. Kennedy International': 'New York',
    'Kiev': 'Kyiv',
    'Hyderabad ': 'Hyderabad',
    'Belgrade': 'Belgrade',
    'Melbourne Australia': 'Melbourne',
    'Yangon': 'Yangon',
    'Singapore Changi Airport': 'Singapore',
    'Chongqing': 'Chongqing',
    'Khartoum': 'Khartoum',
    'Thiruvananthapuram': 'Thiruvananthapuram',
    'Pnom Penh': 'Phnom Penh',
    'Alexandria': 'Alexandria',
    'Taif': 'Taif',
    'Bandaranaike International': 'Colombo',
    'Chhatrapati Shivaji Maharaj International': 'Mumbai',
    'CMN': 'Casablanca',
    'Narita International': 'Tokyo',
    'Tan Son Nhat International': 'Ho Chi Minh City',
    'Tribhuvan International': 'Kathmandu',
    'GOI': 'Goa',
    'CCU': 'Kolkata',
    'BRUvia DOH': 'Brussels',
    'Al Maktoum International': 'Dubai',
    'Queen Alia International': 'Amman',
    'New Delhi': 'New Delhi',
    'JRO': 'Arusha',
    'Charles de Gaulle Airport': 'Paris',
    'Leonardo da Vinci-Fiumicino Airport': 'Rome',
    'Hartsfield-Jackson Atlanta International': 'Atlanta',
    'Venice Marco Polo': 'Venice',
    'O. R. Tambo International': 'Johannesburg',
    'Soekarno-Hatta International': 'Jakarta',
    'Jinnah International': 'Karachi',
    'DAR': 'Dar es Salaam',
    'LHE': 'Lahore',
    'MLE': 'Malé',
    'GVA': 'Geneva',
    'Warsaw Chopin Airport': 'Warsaw',
    "O'Hare International": 'Chicago',
    'Noi Bai International': 'Hanoi',
    'Shanghai Pudong International': 'Shanghai',
    'AKL': 'Auckland',
    'HYD': 'Hyderabad',
    'IST': 'Istanbul',
    'DUR': 'Durban',
    'BEG': 'Belgrade',
    'CNB': 'Coimbatore',
    'VIE': 'Vienna',
    'MCO': 'Orlando',
    'Dallas/Fort Worth International': 'Dallas',
    'goa': 'Goa',
    'DAC': 'Dhaka',
    'Amsterdam Airport Schiphol': 'Amsterdam',
    'YUL': 'Montreal',
    'SNG': 'Singapore',
    'Haneda Airport': 'Tokyo',
    'AMD': 'Ahmedabad',
    'LOS': 'Lagos',
    'Jomo Kenyatta International': 'Nairobi',
    'SYZ': 'Shiraz',
    'Stockholm Arlanda': 'Stockholm',
    'Heydar Aliyev International': 'Baku',
    'STO': 'Stockholm',
    'brussels': 'Brussels',
    'RGN': 'Yangon',
    'Doha airport': 'Doha',
    'Istanbul (SAW)': 'Istanbul',
    'Johanesburg': 'Johannesburg',
    'Suvarnabhumi': 'Bangkok',
    'MIA': 'Miami',
    'Buenos Aires': 'Buenos Aires'
}

# Zamijena imena gradova s točnim punim imenima gradova
df['To'] = df['To'].replace(city_mapping)

# %%
df['To'] = df['To'].replace({'Kuwait City': 'Kuwait', 'Ho Chi Minh City': 'Ho Chi Minh', 'Cebu City': 'Cebu', 'Zanzibar City': 'Zanzibar'})

# %%
df['To'].unique()
# Out:
# array(['London', 'Montreal', 'Perth', 'Doha', 'San Francisco',
#        'Kilimanjaro', 'Melbourne', 'Johannesburg', 'Dubai', 'Adelaide',
#        'Detroit', 'Singapore', 'Auckland', 'Erbil', 'Goa', 'Brussels',
#        'Kolkata', 'Bangkok', 'Frankfurt', 'Sydney', 'Manchester',
#        'Warsaw', 'Tokyo', 'New Delhi', 'Kuala Lumpur', 'Salalah',
#        'Amsterdam', 'Tbilisi', 'Lyon', 'Denpasar', 'Washington', 'Luanda',
#        'Lusaka', 'Milan', 'Kuwait', 'Sao Paulo', 'Chicago', 'Seattle',
#        'Cape Town', 'Brisbane', 'Kathmandu', 'Muscat', 'Athens', 'Vienna',
#        'Rome', 'Manama', 'Colombo', 'Abu Dhabi', 'Istanbul', 'Barcelona',
#        'Paris', 'Phuket', 'Edinburgh', 'Kochi', 'Tehran', 'Mumbai',
#        'Zurich', 'Berlin', 'New York', 'Windhoek', 'Philadelphia',
#        'Riyadh', 'Jakarta', 'Lagos', 'Baghdad', 'Bali', 'Dhaka',
#        'Bucharest', 'Hanoi', 'Dallas', 'Manila', 'Dublin', 'Zagreb',
#        'Madrid', 'Nairobi', 'Bengaluru', 'Sharjah', 'Male', 'Islamabad',
#        'Ho Chi Minh', 'Prague', 'Toronto', 'Karachi', 'Munich', 'Oslo',
#        'Boston', 'Dammam', 'Lahore', 'Miami', 'Hyderabad',
#        'Lapu-Lapu City', 'Cairo', 'Cebu', 'Budapest', 'Atlanta',
#        'Helsinki', 'Beirut', 'Entebbe', 'San Diego', 'Hong Kong',
#        'Nagpur', 'Los Angeles', 'Durban', 'Chennai', 'Amman', 'Kozhikode',
#        'Ahmedabad', 'Stockholm', 'Copenhagen', 'Houston', 'Sialkot',
#        'Medina', 'Baku', 'Moscow', 'Casablanca', 'Larnaca',
#        'Clark Freeport Zone', 'Jeddah', 'Malé', 'Keflavík', 'Basra',
#        'Yerevan', 'Zanzibar', 'Hamilton', 'Seoul', 'Tallinn', 'Vancouver',
#        'Da Nang', 'Najaf', 'St. Petersburg', 'Kyiv', 'Shanghai',
#        'Antalya', 'Sofia', 'Kigali', 'Phnom Penh', 'Gothenburg',
#        'Langkawi', 'George Town', 'Birmingham', 'Multan', nan, 'Venice',
#        'Nice', 'Tunis', 'Ankara', 'Amritsar', 'Rio de Janeiro',
#        'Dar es Salaam', 'Geneva', 'Thiruvananthapuram', 'Cardiff',
#        'Chiang Mai', 'Incheon', 'Guangzhou', 'Belgrade', 'Yangon',
#        'Chongqing', 'Khartoum', 'Alexandria', 'Taif', 'Arusha',
#        'Coimbatore', 'Orlando', 'Shiraz', 'Buenos Aires'], dtype=object)

# %%
df.head()
# Out:
#   Date Published  Rating  Max Rating            Author         Country  \
# 0     2024-03-02     1.0        10.0           Mary Le  United Kingdom
# 1     2024-02-29     1.0        10.0     Brian English          Canada
# 2     2024-02-29     1.0        10.0     Wayne Burgess       Australia
# 3     2024-02-25    10.0        10.0  Alwaleed Althani           Qatar
# 4     2024-02-22     7.0        10.0         W Warnock  United Kingdom
#
#                                    Title  \
# 0             “marred by inconveniences”
# 1                "seat wouldn't stay up"
# 2  "no attempt to address our complaint"
# 3          “I hope they update the A380”
# 4             "I’d rate them maybe 7/10"
#
#                                          Review Body Type Of Traveller  \
# 0   The delay of my flight from Haneda to Doha ca...      Solo Leisure
# 1    They convinced me that I needed to pay $1500...    Couple Leisure
# 2    I have sent 5 emails and have only received ...          Business
# 3   We flew on probably the first A380 the airlin...    Couple Leisure
# 4    Service was ok, pretty good on my aisle and ...    Couple Leisure
#
#         Seat Type     Date Flown  Aircraft                              Route  \
# 0   Economy Class     March 2024       NaN  Tokyo to London Heathrow via Doha
# 1  Business Class  February 2024       NaN                   Doha to Montreal
# 2   Economy Class  November 2023      A380                      Doha to Perth
# 3     First Class  February 2024  A380-800            Doha to London Heathrow
# 4  Business Class  February 2024      A350                   Auckland to Doha
#
#        From     Via        To  Verified Recommended
# 0     Tokyo    Doha    London       0.0          no
# 1      Doha  Direct  Montreal       1.0          no
# 2      Doha  Direct     Perth       1.0          no
# 3      Doha  Direct    London       1.0         Yes
# 4  Auckland  Direct      Doha       1.0          no

# %% [markdown]
# Proces čišćenja podataka za stupce `From` i `To` je uspješno proveden.

# %%
df.isna().sum()
# Out:
# Date Published          0
# Rating                  0
# Max Rating              0
# Author                  0
# Country                 0
# Title                   0
# Review Body             0
# Type Of Traveller       0
# Seat Type               0
# Date Flown              0
# Aircraft             1087
# Route                 437
# From                  425
# Via                     0
# To                    425
# Verified                0
# Recommended             0
# dtype: int64

# %% [markdown]
# Obzirom da ne postoji način da saznamo dodatne informacije o nedostajućim podacima u stupcu `Route`, dropat ćemo ih.

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# Date Published       0
# Rating               0
# Max Rating           0
# Author               0
# Country              0
# Title                0
# Review Body          0
# Type Of Traveller    0
# Seat Type            0
# Date Flown           0
# Aircraft             0
# Route                0
# From                 0
# Via                  0
# To                   0
# Verified             0
# Recommended          0
# dtype: int64

# %% [markdown]
# #### Zamijena dupliciranih / netočnih vrijednosti u stupcu "Via"

# %%
df['Via'].unique()
# Out:
# array(['Direct', 'Doha', 'Phuket', 'Dohs', 'dona', 'Doha & Hong Kong',
#        'Manila', 'Dubai', 'Brussels', 'Dha', 'Entebbe, Doha', 'London',
#        'Adelaide', 'Doha/Sydney', 'DOH', 'Sydney / Doha', 'Bangkok',
#        'Adelaide / Doha', 'Sydney', 'Baku / Doha', 'Doha, Entebbe',
#        'doha', 'SIN', 'BKK / DOH', 'DOA', 'BKK and DOH', 'DXB', 'BRU',
#        'DSOH', 'BKK', 'DOH/BKK', 'BKK, DOH', 'DOH and BKK', 'BKK/DOH',
#        'BKK-DOH-CPH//DOH'], dtype=object)

# %%
mapping = {
    'Dohs': 'Doha',
    'dona': 'Dubai',
    'Doha & Hong Kong': 'Doha',
    'Dha': 'Doha',
    'Entebbe, Doha': 'Doha',
    'Doha/Sydney': 'Doha',
    'DOH': 'Doha',
    'Sydney / Doha': 'Doha',
    'Adelaide / Doha': 'Doha',
    'Baku / Doha': 'Doha',
    'Doha, Entebbe': 'Doha',
    'doha': 'Doha',
    'SIN': 'Singapore',
    'BKK / DOH': 'Bangkok',
    'DOA': 'Doha',
    'BKK and DOH': 'Bangkok',
    'DXB': 'Dubai',
    'BRU': 'Brussels',
    'DSOH': 'Doha',
    'BKK': 'Bangkok',
    'DOH/BKK': 'Bangkok',
    'BKK, DOH': 'Bangkok',
    'DOH and BKK': 'Bangkok',
    'BKK/DOH': 'Bangkok',
    'BKK-DOH-CPH//DOH': 'Bangkok'
}

df['Via'] = df['Via'].replace(mapping)

# %%
# Jedinstvene vrijednosti nakon zamijene dupliciranih ili netočnih u stupcu Via
df['Via'].unique()
# Out:
# array(['Direct', 'Doha', 'Phuket', 'Dubai', 'Manila', 'Brussels',
#        'London', 'Adelaide', 'Bangkok', 'Sydney', 'Singapore'],
#       dtype=object)

# %%
df.isna().sum()
# Out:
# Date Published       0
# Rating               0
# Max Rating           0
# Author               0
# Country              0
# Title                0
# Review Body          0
# Type Of Traveller    0
# Seat Type            0
# Date Flown           0
# Aircraft             0
# Route                0
# From                 0
# Via                  0
# To                   0
# Verified             0
# Recommended          0
# dtype: int64

# %% [markdown]
# ### 🎉 Proces čišćenja podataka uspješno je završen

# %% [markdown]
# <hr>

# %%
# Pretvaranje očišćenih podataka u .csv format
df.to_csv("cleaned_qatar_airways_reviews.csv", index=False)

# %%
df = pd.read_csv("cleaned_qatar_airways_reviews.csv")

# %%
df.sample(15)
# Out:
#      Date Published  Rating  Max Rating            Author         Country  \
# 286      2022-01-21     3.0        10.0    Michael Schade         Germany
# 809      2017-07-03    10.0        10.0        C Stratton  United Kingdom
# 100      2023-05-06     9.0        10.0          S Karsen          Sweden
# 612      2018-08-16     8.0        10.0  Alwaleed Althani           Qatar
# 1189     2015-09-23     5.0        10.0        J Tangyong     Netherlands
# 301      2021-11-01    10.0        10.0   Shabbir Hossain   United States
# 492      2019-06-14     1.0        10.0          E Lamise       Australia
# 690      2018-02-24     3.0        10.0         Jon Theal   United States
# 834      2017-05-16     9.0        10.0          R Dorman           Qatar
# 870      2017-03-22    10.0        10.0         S Thomson          Greece
# 629      2018-06-25     6.0        10.0            J Rigg       Australia
# 228      2022-07-04     1.0        10.0           C Calvi   United States
# 57       2023-09-14     2.0        10.0            V Mann         Germany
# 1223     2015-08-15     5.0        10.0         P Charasz          Poland
# 307      2021-10-21    10.0        10.0     Brett Stewart   United States
#
#                                                   Title  \
# 286                  "inconsistency of seating comfort"
# 809                            "they are streets ahead"
# 100                        "Service on point as always"
# 612                           "the flight was spotless"
# 1189                        "cramped 3-3-3 seat layout"
# 301   "I will always pick Qatar over any other airline"
# 492                            "no bassinets available"
# 690                   "luggage handling is infuriating"
# 834             "Exceptionally fine short haul service"
# 870                            "decent, spacious seats"
# 629                          "one of the best airlines"
# 228               "not been able to locate our baggage"
# 57                 "not able complete the food service"
# 1223                      Qatar Airways customer review
# 307                   "the QR experience was top notch"
#
#                                             Review Body Type Of Traveller  \
# 286     Flight from Warsaw to Doha uneventful; reaso...      Solo Leisure
# 809   ✅ Verified Review |  First time on Qatar Airwa...    Family Leisure
# 100     Always good to travel business in a Boeing 7...      Solo Leisure
# 612     Paris to Doha. We had a ONE WORLD logo aircr...    Family Leisure
# 1189  Was looking forward to experience Qatar Airway...      Solo Leisure
# 301    This is my fourth time flying Qatar in busine...      Solo Leisure
# 492     We are extremely disappointed at the treatme...    Family Leisure
# 690     Chicago to Doha. I saw the ticket agent phys...          Business
# 834   ✅ Verified Review |  Doha to Riyadh. Exception...          Business
# 870   ✅ Verified Review |  Check in at Athens Airpor...          Business
# 629    Adelaide to Doha. The seats are not designed ...      Solo Leisure
# 228     The flight itself was fine however dealing w...    Couple Leisure
# 57     Cabin staff service: Inflight staff is very i...    Family Leisure
# 1223  WAW-DOH on an A320. Seat was uncomfortable. He...      Solo Leisure
# 307     We were originally scheduled to fly SFO-DOH-...          Business
#
#            Seat Type      Date Flown                      Aircraft  \
# 286   Business Class    January 2022            Boeing 787 / AB332
# 809   Business Class       June 2017                   A380 / A330
# 100   Business Class      March 2023                  Boeing 787-8
# 612   Business Class     August 2018                      A350-900
# 1189   Economy Class    January 2015                    Boeing 787
# 301   Business Class    October 2021                      A350-900
# 492    Economy Class       June 2019                          A380
# 690    Economy Class   February 2018                Boeing 777-300
# 834      First Class        May 2017                          A330
# 870    Economy Class      March 2017               A320/200 & A350
# 629   Business Class       June 2018                          A350
# 228    Economy Class       July 2022                          A350
# 57     Economy Class  September 2023                    Boeing 787
# 1223   Economy Class       July 2015                     A320/A350
# 307   Business Class    October 2021  A350-1000 / Boeing 777-300ER
#
#                                    Route                   From     Via  \
# 286           Warsaw to Bangkok via Doha                 Warsaw    Doha
# 809              London to Bali via Doha                 London    Doha
# 100                    Stockholm to Doha              Stockholm  Direct
# 612                        Paris to Doha                  Paris  Direct
# 1189                      Munich to Doha                 Munich  Direct
# 301            Dhaka to Atlanta via Doha                  Dhaka    Doha
# 492          Melbourne to Milan via Doha              Melbourne    Doha
# 690                      Chicago to Doha                Chicago  Direct
# 834                       Doha to Riyadh                   Doha  Direct
# 870             Athens to Dubai via Doha                 Athens    Doha
# 629                     Adelaide to Doha               Adelaide  Direct
# 228      Los Angeles to Nairobi via Doha            Los Angeles    Doha
# 57          Mumbai to Frankfurt via Doha                 Mumbai    Doha
# 1223                  WAW to SIN via DOH  Warsaw Chopin Airport    Doha
# 307   San Francisco to Brisbane via Doha          San Francisco    Doha
#
#              To  Verified Recommended
# 286     Bangkok       1.0          no
# 809        Bali       1.0         Yes
# 100        Doha       1.0         Yes
# 612        Doha       1.0         Yes
# 1189       Doha       0.0          no
# 301     Atlanta       1.0         Yes
# 492       Milan       1.0          no
# 690        Doha       1.0          no
# 834      Riyadh       1.0         Yes
# 870       Dubai       1.0         Yes
# 629        Doha       1.0          no
# 228     Nairobi       1.0          no
# 57    Frankfurt       1.0          no
# 1223  Singapore       0.0          no
# 307    Brisbane       1.0         Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1278 entries, 0 to 1277
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date Published     1278 non-null   object
#  1   Rating             1278 non-null   float64
#  2   Max Rating         1278 non-null   float64
#  3   Author             1278 non-null   object
#  4   Country            1278 non-null   object
#  5   Title              1278 non-null   object
#  6   Review Body        1278 non-null   object
#  7   Type Of Traveller  1278 non-null   object
#  8   Seat Type          1278 non-null   object
#  9   Date Flown         1278 non-null   object
#  10  Aircraft           1278 non-null   object
#  11  Route              1278 non-null   object
#  12  From               1278 non-null   object
#  13  Via                1278 non-null   object
#  14  To                 1278 non-null   object
#  15  Verified           1278 non-null   float64
#  16  Recommended        1278 non-null   object
# dtypes: float64(3), object(14)
# memory usage: 169.9+ KB

# %%
df.describe()
# Out:
#             Rating  Max Rating     Verified
# count  1278.000000      1278.0  1278.000000
# mean      7.758998        10.0     0.763693
# std       2.531520         0.0     0.424979
# min       1.000000        10.0     0.000000
# 25%       6.000000        10.0     1.000000
# 50%       9.000000        10.0     1.000000
# 75%      10.000000        10.0     1.000000
# max      10.000000        10.0     1.000000

# %%
df.isna().sum()
# Out:
# Date Published       0
# Rating               0
# Max Rating           0
# Author               0
# Country              0
# Title                0
# Review Body          0
# Type Of Traveller    0
# Seat Type            0
# Date Flown           0
# Aircraft             0
# Route                0
# From                 0
# Via                  0
# To                   0
# Verified             0
# Recommended          0
# dtype: int64
